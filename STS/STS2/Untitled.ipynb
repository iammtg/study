# %%
#ファイル入力
def file_input(input_path,output_path):
    with open(input_path) as f:
        s = f.read()
    s = s.strip().replace('\t','\n').replace('.','')
    sentences = s.split('\n')
    
    ps = PorterStemmer()
    for i in range(len(sentences)):
        token = sentences[i].split(' ')
        singles = [ps.stem(plural) for plural in token]
        sentences[i] = singles
    return sentences

# %%
# 単語IDの登録
def word_to_id(sentences:list):
    word_id_list = {}
    id_count = 0
    for sentence in sentences:
        for token in sentence:
            if(token not in word_id_list):        
                word_id_list[token] = id_count
                id_count += 1
    return word_id_list

# %%
#単語からワンホットベクトル列を入手。
def word_to_vector(word:str,dim,word_id_list:dict):
    X = torch.zeros(dim)
    X[word_id_list[word]] = 1.0
    return X
# word_to_vector('young',dim,word_id_list)
# print(word_id_list['young'])

# %%
def create_contexts_target(sentences:list):
    x = []
    y = []
    for sentence in sentences:
        l = len(sentence)
        for i in range(l-2):
            v1 = word_to_vector(sentence[i],dim,word_id_list)
            v2 = word_to_vector(sentence[i+2],dim,word_id_list)
            list = [v1,v2]
            x.append(list)
            y.append(word_to_vector(sentence[i+1],dim,word_id_list))
    return x,y

# %%
class Embedding(nn.Module):
    def __init__(self,in_dim,out_dim):
        super().__init__()
        self.W_in = nn.Parameter(torch.tensor(rn))

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy import spatial
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.stem.porter import PorterStemmer
import numpy as np
import torch
import random
input_path = '../test_data/STS.input.images.txt'
#input_path = '../test_data/testinput.txt'
output_path = './output/STS.output.images.txt'
#output_path = './output/testoutput.txt'
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')

#ファイル入力
sentences = file_input(input_path,output_path)
#sentences = sentences[0:10]
#print(sentences)

word_id_list = word_to_id(sentences)
#print(word_id_list)
#print(word_id_list)
dim = len(word_id_list)

x,y = create_contexts_target(sentences)
random.shuffle(x)
random.shuffle(y)
vocab_size = len(x)
print(vocab_size)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fox25\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 10687

# %%
# Out:
# start
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import urllib.request
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk import word_tokenize
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances

torch.manual_seed(1)

CONTEXT_SIZE = 3
EMBEDDING_DIM = 10

test_sentence = """Empathy for the poor may not come easily to people who never experienced it. They may blame the victims and insist their predicament can be overcome through determination and hard work.
But they may not realize that extreme poverty can be psychologically and physically incapacitating — a perpetual cycle of bad diets, health care and education exacerbated by the shaming and self-fulfilling prophecies that define it in the public imagination.
Gordon Parks — perhaps more than any artist — saw poverty as “the most savage of all human afflictions” and realized the power of empathy to help us understand it. It was neither an abstract problem nor political symbol, but something he endured growing up destitute in rural Kansas and having spent years documenting poverty throughout the world, including the United States.
That sensitivity informed “Freedom’s Fearful Foe: Poverty,” his celebrated photo essay published in Life magazine in June 1961. He took readers into the lives of a Brazilian boy, Flavio da Silva, and his family, who lived in the ramshackle Catacumba favela in the hills outside Rio de Janeiro. These stark photographs are the subject of a new book, “Gordon Parks: The Flavio Story” (Steidl/The Gordon Parks Foundation), which accompanies a traveling exhibition co-organized by the Ryerson Image Centre in Toronto, where it opens this week, and the J. Paul Getty Museum. Edited with texts by the exhibition’s co-curators, Paul Roth and Amanda Maddox, the book also includes a recent interview with Mr. da Silva and essays by Beatriz Jaguaribe, Maria Alice Rezende de Carvalho and Sérgio Burgi.
""".split()
# we should tokenize the input, but we will ignore that for now
# build a list of tuples.  Each tuple is ([ word_i-2, word_i-1 ], target word)

#print(test_sentence)
print(len(test_sentence))
def get_key(word_id):
    for key,val in word_to_ix.items():
        if(val == word_id):
            print(key)

def cluster_embeddings(filename,nclusters):
    X = np.load(filename)
    kmeans = KMeans(n_clusters=nclusters, random_state=0).fit(X)
    center = kmeans.cluster_centers_
    distances = euclidean_distances(X,center)

    for i in np.arange(0,distances.shape[1]):
        word_id = np.argmin(distances[:,i])
        print(word_id)
        get_key(word_id)

def read_data(file_path):
    tokenizer = RegexpTokenizer(r'\w+')
    data = urllib.request.urlopen(file_path)
    data = data.read().decode('utf8')
    tokenized_data = word_tokenize(data)
    stop_words = set(stopwords.words('english'))
    stop_words.update(['.',',',':',';','(',')','#','--','...','"'])
    cleaned_words = [ i for i in tokenized_data if i not in stop_words ]
    return(cleaned_words)

#test_sentence = read_data('https://www.gutenberg.org/files/57884/57884-0.txt')

ngrams = []
for i in range(len(test_sentence) - CONTEXT_SIZE):
    tup = [test_sentence[j] for j in np.arange(i , i + CONTEXT_SIZE) ]
    ngrams.append((tup,test_sentence[i + CONTEXT_SIZE]))
# print the first 3, just so you can see what they look like
#print(ngrams)


vocab = set(test_sentence)
print(vocab)
print("Length of vocabulary",len(vocab))
word_to_ix = {word: i for i, word in enumerate(vocab)}
print(word_to_ix)


class CBOWModeler(nn.Module):

    def __init__(self, vocab_size, embedding_dim, context_size):
        super(CBOWModeler, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear1 = nn.Linear(context_size * embedding_dim, 128)
        self.linear2 = nn.Linear(128, vocab_size)

    def forward(self, inputs):
        embeds = self.embeddings(inputs).view((1, -1))  # -1 implies size inferred for that index from the size of the data
        #print(np.mean(np.mean(self.linear2.weight.data.numpy())))
        out1 = F.relu(self.linear1(embeds)) # output of first layer
        out2 = self.linear2(out1)           # output of second layer
        #print(embeds)
        log_probs = F.log_softmax(out2, dim=1)
        return log_probs

    def predict(self,input):
        context_idxs = torch.tensor([word_to_ix[w] for w in input], dtype=torch.long)
        res = self.forward(context_idxs)
        res_arg = torch.argmax(res)
        res_val, res_ind = res.sort(descending=True)
        res_val = res_val[0][:3]
        res_ind = res_ind[0][:3]
        #print(res_val)
        #print(res_ind)
        for arg in zip(res_val,res_ind):
            #print(arg)
            print([(key,val,arg[0]) for key,val in word_to_ix.items() if val == arg[1]])

    def freeze_layer(self,layer):
        for name,child in model.named_children():
            print(name,child)
            if(name == layer):
                for names,params in child.named_parameters():
                    print(names,params)
                    print(params.size())
                    params.requires_grad= False

    def print_layer_parameters(self):
        for name,child in model.named_children():
                print(name,child)
                for names,params in child.named_parameters():
                    print(names,params)
                    print(params.size())

    def write_embedding_to_file(self,filename):
        for i in self.embeddings.parameters():
            weights = i.data.numpy()
        np.save(filename,weights)



losses = []
loss_function = nn.NLLLoss()
model = CBOWModeler(len(vocab), EMBEDDING_DIM, CONTEXT_SIZE)
optimizer = optim.SGD(model.parameters(), lr=0.001)

# Freeze embedding layer
#model.freeze_layer('embeddings')


for epoch in range(400):
    total_loss = 0
    #------- Embedding layers are trained as well here ----#
    #lookup_tensor = torch.tensor([word_to_ix["poor"]], dtype=torch.long)
    #hello_embed = model.embeddings(lookup_tensor)
    #print(hello_embed)
    # -----------------------------------------------------#

    for context, target in ngrams:

        # Step 1. Prepare the inputs to be passed to the model (i.e, turn the words
        # into integer indices and wrap them in tensors)
        context_idxs = torch.tensor([word_to_ix[w] for w in context], dtype=torch.long)
        #print("Context id",context_idxs)

        # Step 2. Recall that torch *accumulates* gradients. Before passing in a
        # new instance, you need to zero out the gradients from the old
        # instance
        model.zero_grad()

        # Step 3. Run the forward pass, getting log probabilities over next
        # words
        print(epoch)
        print(context_idxs)
        log_probs = model(context_idxs)
        #print(log_probs)

        # Step 4. Compute your loss function. (Again, Torch wants the target
        # word wrapped in a tensor)
        loss = loss_function(log_probs, torch.tensor([word_to_ix[target]], dtype=torch.long))
        #print(loss)

        # Step 5. Do the backward pass and update the gradient
        loss.backward()
        optimizer.step()

        # Get the Python number from a 1-element Tensor by calling tensor.item()
        total_loss += loss.item()
    print(total_loss)
    losses.append(total_loss)
#print(losses)  # The loss decreased every iteration over the training data!

#Print the model layer parameters
#model.print_layer_parameters()

#Predict the next word given n context words
model.predict(['of','all','human'])
model.write_embedding_to_file('embeddings.npy')
cluster_embeddings('embeddings.npy',2)
# Out:
# 259
# {'Paul', 'education', 'something', 'da', 'exacerbated', 'lived', 'Carvalho', 'was', 'problem', 'book', 'favela', 'work.', 'victims', 'cycle', 'It', 'Foundation),', 'this', 'hard', 'Gordon', 'Poverty,”', 'Mr.', 'empathy', 'Jaguaribe,', 'Maddox,', 'experienced', 'through', 'essay', 'insist', 'prophecies', 'people', 'where', 'Foe:', 'us', 'Maria', 'blame', 'by', 'exhibition’s', 'perpetual', 'also', 'Image', 'and', 'overcome', 'texts', 'These', 'their', 'week,', 'Brazilian', 'can', 'that', 'of', 'political', 'artist', 'years', 'includes', 'Janeiro.', 'opens', 'United', 'having', 'readers', 'boy,', 'recent', 'magazine', 'symbol,', 'shaming', 'neither', 'Getty', 'not', 'informed', 'Amanda', 'for', 'any', '(Steidl/The', 'to', 'accompanies', 'Edited', 'self-fulfilling', 'Flavio', 'Silva', 'Burgi.', 'photographs', 'may', '“Freedom’s', 'throughout', '1961.', 'extreme', 'who', '—', 'Parks', 'all', 'imagination.', 'interview', 'endured', 'Empathy', '“the', 'are', 'Alice', 'in', 'never', 'perhaps', 'co-organized', 'he', 'into', 'health', 'lives', 'Catacumba', 'more', 'define', 'co-curators,', '“Gordon', 'exhibition', 'took', 'Centre', 'saw', 'help', 'growing', 'Ryerson', 'understand', 'a', 'family,', 'Parks:', 'power', 'June', 'Toronto,', 'world,', 'photo', 'which', 'Beatriz', 'savage', 'Kansas', 'with', 'essays', 'spent', 'incapacitating', 'it', 'They', 'That', 'realized', 'predicament', 'they', 'than', 'destitute', 'come', 'bad', 'But', 'The', 'an', 'Silva,', 'documenting', 'States.', 'his', 'Museum.', 'new', 'Story”', 'physically', 'realize', 'Roth', 'most', 'but', 'ramshackle', 'published', 'afflictions”', 'traveling', 'Life', 'easily', 'Sérgio', 'Rio', 'stark', 'celebrated', 'it.', 'public', 'rural', 'book,', 'Rezende', 'J.', 'sensitivity', 'up', 'including', 'de', 'psychologically', 'poor', 'the', 'care', 'abstract', 'be', 'determination', 'Fearful', 'poverty', 'outside', 'as', 'hills', 'He', 'nor', 'subject', 'diets,', 'human'}
# Length of vocabulary 195
# {'Paul': 0, 'education': 1, 'something': 2, 'da': 3, 'exacerbated': 4, 'lived': 5, 'Carvalho': 6, 'was': 7, 'problem': 8, 'book': 9, 'favela': 10, 'work.': 11, 'victims': 12, 'cycle': 13, 'It': 14, 'Foundation),': 15, 'this': 16, 'hard': 17, 'Gordon': 18, 'Poverty,”': 19, 'Mr.': 20, 'empathy': 21, 'Jaguaribe,': 22, 'Maddox,': 23, 'experienced': 24, 'through': 25, 'essay': 26, 'insist': 27, 'prophecies': 28, 'people': 29, 'where': 30, 'Foe:': 31, 'us': 32, 'Maria': 33, 'blame': 34, 'by': 35, 'exhibition’s': 36, 'perpetual': 37, 'also': 38, 'Image': 39, 'and': 40, 'overcome': 41, 'texts': 42, 'These': 43, 'their': 44, 'week,': 45, 'Brazilian': 46, 'can': 47, 'that': 48, 'of': 49, 'political': 50, 'artist': 51, 'years': 52, 'includes': 53, 'Janeiro.': 54, 'opens': 55, 'United': 56, 'having': 57, 'readers': 58, 'boy,': 59, 'recent': 60, 'magazine': 61, 'symbol,': 62, 'shaming': 63, 'neither': 64, 'Getty': 65, 'not': 66, 'informed': 67, 'Amanda': 68, 'for': 69, 'any': 70, '(Steidl/The': 71, 'to': 72, 'accompanies': 73, 'Edited': 74, 'self-fulfilling': 75, 'Flavio': 76, 'Silva': 77, 'Burgi.': 78, 'photographs': 79, 'may': 80, '“Freedom’s': 81, 'throughout': 82, '1961.': 83, 'extreme': 84, 'who': 85, '—': 86, 'Parks': 87, 'all': 88, 'imagination.': 89, 'interview': 90, 'endured': 91, 'Empathy': 92, '“the': 93, 'are': 94, 'Alice': 95, 'in': 96, 'never': 97, 'perhaps': 98, 'co-organized': 99, 'he': 100, 'into': 101, 'health': 102, 'lives': 103, 'Catacumba': 104, 'more': 105, 'define': 106, 'co-curators,': 107, '“Gordon': 108, 'exhibition': 109, 'took': 110, 'Centre': 111, 'saw': 112, 'help': 113, 'growing': 114, 'Ryerson': 115, 'understand': 116, 'a': 117, 'family,': 118, 'Parks:': 119, 'power': 120, 'June': 121, 'Toronto,': 122, 'world,': 123, 'photo': 124, 'which': 125, 'Beatriz': 126, 'savage': 127, 'Kansas': 128, 'with': 129, 'essays': 130, 'spent': 131, 'incapacitating': 132, 'it': 133, 'They': 134, 'That': 135, 'realized': 136, 'predicament': 137, 'they': 138, 'than': 139, 'destitute': 140, 'come': 141, 'bad': 142, 'But': 143, 'The': 144, 'an': 145, 'Silva,': 146, 'documenting': 147, 'States.': 148, 'his': 149, 'Museum.': 150, 'new': 151, 'Story”': 152, 'physically': 153, 'realize': 154, 'Roth': 155, 'most': 156, 'but': 157, 'ramshackle': 158, 'published': 159, 'afflictions”': 160, 'traveling': 161, 'Life': 162, 'easily': 163, 'Sérgio': 164, 'Rio': 165, 'stark': 166, 'celebrated': 167, 'it.': 168, 'public': 169, 'rural': 170, 'book,': 171, 'Rezende': 172, 'J.': 173, 'sensitivity': 174, 'up': 175, 'including': 176, 'de': 177, 'psychologically': 178, 'poor': 179, 'the': 180, 'care': 181, 'abstract': 182, 'be': 183, 'determination': 184, 'Fearful': 185, 'poverty': 186, 'outside': 187, 'as': 188, 'hills': 189, 'He': 190, 'nor': 191, 'subject': 192, 'diets,': 193, 'human': 194}
# 0
# tensor([ 92,  69, 180])
# 0
# tensor([ 69, 180, 179])
# 0
# tensor([180, 179,  80])
# 0
# tensor([179,  80,  66])
# 0
# tensor([ 80,  66, 141])
# 0
# tensor([ 66, 141, 163])
# 0
# tensor([141, 163,  72])
# 0
# tensor([163,  72,  29])
# 0
# tensor([72, 29, 85])
# 0
# tensor([29, 85, 97])
# 0
# tensor([85, 97, 24])
# 0
# tensor([ 97,  24, 168])
# 0
# tensor([ 24, 168, 134])
# 0
# tensor([168, 134,  80])
# 0
# tensor([134,  80,  34])
# 0
# tensor([ 80,  34, 180])
# 0
# tensor([ 34, 180,  12])
# 0
# tensor([180,  12,  40])
# 0
# tensor([12, 40, 27])
# 0
# tensor([40, 27, 44])
# 0
# tensor([ 27,  44, 137])
# 0
# tensor([ 44, 137,  47])
# 0
# tensor([137,  47, 183])
# 0
# tensor([ 47, 183,  41])
# 0
# tensor([183,  41,  25])
# 0
# tensor([ 41,  25, 184])
# 0
# tensor([ 25, 184,  40])
# 0
# tensor([184,  40,  17])
# 0
# tensor([40, 17, 11])
# 0
# tensor([ 17,  11, 143])
# 0
# tensor([ 11, 143, 138])
# 0
# tensor([143, 138,  80])
# 0
# tensor([138,  80,  66])
# 0
# tensor([ 80,  66, 154])
# 0
# tensor([ 66, 154,  48])
# 0
# tensor([154,  48,  84])
# 0
# tensor([ 48,  84, 186])
# 0
# tensor([ 84, 186,  47])
# 0
# tensor([186,  47, 183])
# 0
# tensor([ 47, 183, 178])
# 0
# tensor([183, 178,  40])
# 0
# tensor([178,  40, 153])
# 0
# tensor([ 40, 153, 132])
# 0
# tensor([153, 132,  86])
# 0
# tensor([132,  86, 117])
# 0
# tensor([ 86, 117,  37])
# 0
# tensor([117,  37,  13])
# 0
# tensor([37, 13, 49])
# 0
# tensor([ 13,  49, 142])
# 0
# tensor([ 49, 142, 193])
# 0
# tensor([142, 193, 102])
# 0
# tensor([193, 102, 181])
# 0
# tensor([102, 181,  40])
# 0
# tensor([181,  40,   1])
# 0
# tensor([40,  1,  4])
# 0
# tensor([ 1,  4, 35])
# 0
# tensor([  4,  35, 180])
# 0
# tensor([ 35, 180,  63])
# 0
# tensor([180,  63,  40])
# 0
# tensor([63, 40, 75])
# 0
# tensor([40, 75, 28])
# 0
# tensor([75, 28, 48])
# 0
# tensor([ 28,  48, 106])
# 0
# tensor([ 48, 106, 133])
# 0
# tensor([106, 133,  96])
# 0
# tensor([133,  96, 180])
# 0
# tensor([ 96, 180, 169])
# 0
# tensor([180, 169,  89])
# 0
# tensor([169,  89,  18])
# 0
# tensor([89, 18, 87])
# 0
# tensor([18, 87, 86])
# 0
# tensor([87, 86, 98])
# 0
# tensor([ 86,  98, 105])
# 0
# tensor([ 98, 105, 139])
# 0
# tensor([105, 139,  70])
# 0
# tensor([139,  70,  51])
# 0
# tensor([70, 51, 86])
# 0
# tensor([ 51,  86, 112])
# 0
# tensor([ 86, 112, 186])
# 0
# tensor([112, 186, 188])
# 0
# tensor([186, 188,  93])
# 0
# tensor([188,  93, 156])
# 0
# tensor([ 93, 156, 127])
# 0
# tensor([156, 127,  49])
# 0
# tensor([127,  49,  88])
# 0
# tensor([ 49,  88, 194])
# 0
# tensor([ 88, 194, 160])
# 0
# tensor([194, 160,  40])
# 0
# tensor([160,  40, 136])
# 0
# tensor([ 40, 136, 180])
# 0
# tensor([136, 180, 120])
# 0
# tensor([180, 120,  49])
# 0
# tensor([120,  49,  21])
# 0
# tensor([49, 21, 72])
# 0
# tensor([ 21,  72, 113])
# 0
# tensor([ 72, 113,  32])
# 0
# tensor([113,  32, 116])
# 0
# tensor([ 32, 116, 168])
# 0
# tensor([116, 168,  14])
# 0
# tensor([168,  14,   7])
# 0
# tensor([14,  7, 64])
# 0
# tensor([  7,  64, 145])
# 0
# tensor([ 64, 145, 182])
# 0
# tensor([145, 182,   8])
# 0
# tensor([182,   8, 191])
# 0
# tensor([  8, 191,  50])
# 0
# tensor([191,  50,  62])
# 0
# tensor([ 50,  62, 157])
# 0
# tensor([ 62, 157,   2])
# 0
# tensor([157,   2, 100])
# 0
# tensor([  2, 100,  91])
# 0
# tensor([100,  91, 114])
# 0
# tensor([ 91, 114, 175])
# 0
# tensor([114, 175, 140])
# 0
# tensor([175, 140,  96])
# 0
# tensor([140,  96, 170])
# 0
# tensor([ 96, 170, 128])
# 0
# tensor([170, 128,  40])
# 0
# tensor([128,  40,  57])
# 0
# tensor([ 40,  57, 131])
# 0
# tensor([ 57, 131,  52])
# 0
# tensor([131,  52, 147])
# 0
# tensor([ 52, 147, 186])
# 0
# tensor([147, 186,  82])
# 0
# tensor([186,  82, 180])
# 0
# tensor([ 82, 180, 123])
# 0
# tensor([180, 123, 176])
# 0
# tensor([123, 176, 180])
# 0
# tensor([176, 180,  56])
# 0
# tensor([180,  56, 148])
# 0
# tensor([ 56, 148, 135])
# 0
# tensor([148, 135, 174])
# 0
# tensor([135, 174,  67])
# 0
# tensor([174,  67,  81])
# 0
# tensor([ 67,  81, 185])
# 0
# tensor([ 81, 185,  31])
# 0
# tensor([185,  31,  19])
# 0
# tensor([ 31,  19, 149])
# 0
# tensor([ 19, 149, 167])
# 0
# tensor([149, 167, 124])
# 0
# tensor([167, 124,  26])
# 0
# tensor([124,  26, 159])
# 0
# tensor([ 26, 159,  96])
# 0
# tensor([159,  96, 162])
# 0
# tensor([ 96, 162,  61])
# 0
# tensor([162,  61,  96])
# 0
# tensor([ 61,  96, 121])
# 0
# tensor([ 96, 121,  83])
# 0
# tensor([121,  83, 190])
# 0
# tensor([ 83, 190, 110])
# 0
# tensor([190, 110,  58])
# 0
# tensor([110,  58, 101])
# 0
# tensor([ 58, 101, 180])
# 0
# tensor([101, 180, 103])
# 0
# tensor([180, 103,  49])
# 0
# tensor([103,  49, 117])
# 0
# tensor([ 49, 117,  46])
# 0
# tensor([117,  46,  59])
# 0
# tensor([46, 59, 76])
# 0
# tensor([59, 76,  3])
# 0
# tensor([ 76,   3, 146])
# 0
# tensor([  3, 146,  40])
# 0
# tensor([146,  40, 149])
# 0
# tensor([ 40, 149, 118])
# 0
# tensor([149, 118,  85])
# 0
# tensor([118,  85,   5])
# 0
# tensor([85,  5, 96])
# 0
# tensor([  5,  96, 180])
# 0
# tensor([ 96, 180, 158])
# 0
# tensor([180, 158, 104])
# 0
# tensor([158, 104,  10])
# 0
# tensor([104,  10,  96])
# 0
# tensor([ 10,  96, 180])
# 0
# tensor([ 96, 180, 189])
# 0
# tensor([180, 189, 187])
# 0
# tensor([189, 187, 165])
# 0
# tensor([187, 165, 177])
# 0
# tensor([165, 177,  54])
# 0
# tensor([177,  54,  43])
# 0
# tensor([ 54,  43, 166])
# 0
# tensor([ 43, 166,  79])
# 0
# tensor([166,  79,  94])
# 0
# tensor([ 79,  94, 180])
# 0
# tensor([ 94, 180, 192])
# 0
# tensor([180, 192,  49])
# 0
# tensor([192,  49, 117])
# 0
# tensor([ 49, 117, 151])
# 0
# tensor([117, 151, 171])
# 0
# tensor([151, 171, 108])
# 0
# tensor([171, 108, 119])
# 0
# tensor([108, 119, 144])
# 0
# tensor([119, 144,  76])
# 0
# tensor([144,  76, 152])
# 0
# tensor([ 76, 152,  71])
# 0
# tensor([152,  71,  18])
# 0
# tensor([71, 18, 87])
# 0
# tensor([18, 87, 15])
# 0
# tensor([ 87,  15, 125])
# 0
# tensor([ 15, 125,  73])
# 0
# tensor([125,  73, 117])
# 0
# tensor([ 73, 117, 161])
# 0
# tensor([117, 161, 109])
# 0
# tensor([161, 109,  99])
# 0
# tensor([109,  99,  35])
# 0
# tensor([ 99,  35, 180])
# 0
# tensor([ 35, 180, 115])
# 0
# tensor([180, 115,  39])
# 0
# tensor([115,  39, 111])
# 0
# tensor([ 39, 111,  96])
# 0
# tensor([111,  96, 122])
# 0
# tensor([ 96, 122,  30])
# 0
# tensor([122,  30, 133])
# 0
# tensor([ 30, 133,  55])
# 0
# tensor([133,  55,  16])
# 0
# tensor([55, 16, 45])
# 0
# tensor([16, 45, 40])
# 0
# tensor([ 45,  40, 180])
# 0
# tensor([ 40, 180, 173])
# 0
# tensor([180, 173,   0])
# 0
# tensor([173,   0,  65])
# 0
# tensor([  0,  65, 150])
# 0
# tensor([ 65, 150,  74])
# 0
# tensor([150,  74, 129])
# 0
# tensor([ 74, 129,  42])
# 0
# tensor([129,  42,  35])
# 0
# tensor([ 42,  35, 180])
# 0
# tensor([ 35, 180,  36])
# 0
# tensor([180,  36, 107])
# 0
# tensor([ 36, 107,   0])
# 0
# tensor([107,   0, 155])
# 0
# tensor([  0, 155,  40])
# 0
# tensor([155,  40,  68])
# 0
# tensor([40, 68, 23])
# 0
# tensor([ 68,  23, 180])
# 0
# tensor([ 23, 180,   9])
# 0
# tensor([180,   9,  38])
# 0
# tensor([ 9, 38, 53])
# 0
# tensor([ 38,  53, 117])
# 0
# tensor([ 53, 117,  60])
# 0
# tensor([117,  60,  90])
# 0
# tensor([ 60,  90, 129])
# 0
# tensor([ 90, 129,  20])
# 0
# tensor([129,  20,   3])
# 0
# tensor([20,  3, 77])
# 0
# tensor([ 3, 77, 40])
# 0
# tensor([ 77,  40, 130])
# 0
# tensor([ 40, 130,  35])
# 0
# tensor([130,  35, 126])
# 0
# tensor([ 35, 126,  22])
# 0
# tensor([126,  22,  33])
# 0
# tensor([22, 33, 95])
# 0
# tensor([ 33,  95, 172])
# 0
# tensor([ 95, 172, 177])
# 0
# tensor([172, 177,   6])
# 0
# tensor([177,   6,  40])
# 0
# tensor([  6,  40, 164])
# 1364.6369261741638
# 1
# tensor([ 92,  69, 180])
# 1
# tensor([ 69, 180, 179])
# 1
# tensor([180, 179,  80])
# 1
# tensor([179,  80,  66])
# 1
# tensor([ 80,  66, 141])
# 1
# tensor([ 66, 141, 163])
# 1
# tensor([141, 163,  72])
# 1
# tensor([163,  72,  29])
# 1
# tensor([72, 29, 85])
# 1
# tensor([29, 85, 97])
# 1
# tensor([85, 97, 24])
# 1
# tensor([ 97,  24, 168])
# 1
# tensor([ 24, 168, 134])
# 1
# tensor([168, 134,  80])
# 1
# tensor([134,  80,  34])
# 1
# tensor([ 80,  34, 180])
# 1
# tensor([ 34, 180,  12])
# 1
# tensor([180,  12,  40])
# 1
# tensor([12, 40, 27])
# 1
# tensor([40, 27, 44])
# 1
# tensor([ 27,  44, 137])
# 1
# tensor([ 44, 137,  47])
# 1
# tensor([137,  47, 183])
# 1
# tensor([ 47, 183,  41])
# 1
# tensor([183,  41,  25])
# 1
# tensor([ 41,  25, 184])
# 1
# tensor([ 25, 184,  40])
# 1
# tensor([184,  40,  17])
# 1
# tensor([40, 17, 11])
# 1
# tensor([ 17,  11, 143])
# 1
# tensor([ 11, 143, 138])
# 1
# tensor([143, 138,  80])
# 1
# tensor([138,  80,  66])
# 1
# tensor([ 80,  66, 154])
# 1
# tensor([ 66, 154,  48])
# 1
# tensor([154,  48,  84])
# 1
# tensor([ 48,  84, 186])
# 1
# tensor([ 84, 186,  47])
# 1
# tensor([186,  47, 183])
# 1
# tensor([ 47, 183, 178])
# 1
# tensor([183, 178,  40])
# 1
# tensor([178,  40, 153])
# 1
# tensor([ 40, 153, 132])
# 1
# tensor([153, 132,  86])
# 1
# tensor([132,  86, 117])
# 1
# tensor([ 86, 117,  37])
# 1
# tensor([117,  37,  13])
# 1
# tensor([37, 13, 49])
# 1
# tensor([ 13,  49, 142])
# 1
# tensor([ 49, 142, 193])
# 1
# tensor([142, 193, 102])
# 1
# tensor([193, 102, 181])
# 1
# tensor([102, 181,  40])
# 1
# tensor([181,  40,   1])
# 1
# tensor([40,  1,  4])
# 1
# tensor([ 1,  4, 35])
# 1
# tensor([  4,  35, 180])
# 1
# tensor([ 35, 180,  63])
# 1
# tensor([180,  63,  40])
# 1
# tensor([63, 40, 75])
# 1
# tensor([40, 75, 28])
# 1
# tensor([75, 28, 48])
# 1
# tensor([ 28,  48, 106])
# 1
# tensor([ 48, 106, 133])
# 1
# tensor([106, 133,  96])
# 1
# tensor([133,  96, 180])
# 1
# tensor([ 96, 180, 169])
# 1
# tensor([180, 169,  89])
# 1
# tensor([169,  89,  18])
# 1
# tensor([89, 18, 87])
# 1
# tensor([18, 87, 86])
# 1
# tensor([87, 86, 98])
# 1
# tensor([ 86,  98, 105])
# 1
# tensor([ 98, 105, 139])
# 1
# tensor([105, 139,  70])
# 1
# tensor([139,  70,  51])
# 1
# tensor([70, 51, 86])
# 1
# tensor([ 51,  86, 112])
# 1
# tensor([ 86, 112, 186])
# 1
# tensor([112, 186, 188])
# 1
# tensor([186, 188,  93])
# 1
# tensor([188,  93, 156])
# 1
# tensor([ 93, 156, 127])
# 1
# tensor([156, 127,  49])
# 1
# tensor([127,  49,  88])
# 1
# tensor([ 49,  88, 194])
# 1
# tensor([ 88, 194, 160])
# 1
# tensor([194, 160,  40])
# 1
# tensor([160,  40, 136])
# 1
# tensor([ 40, 136, 180])
# 1
# tensor([136, 180, 120])
# 1
# tensor([180, 120,  49])
# 1
# tensor([120,  49,  21])
# 1
# tensor([49, 21, 72])
# 1
# tensor([ 21,  72, 113])
# 1
# tensor([ 72, 113,  32])
# 1
# tensor([113,  32, 116])
# 1
# tensor([ 32, 116, 168])
# 1
# tensor([116, 168,  14])
# 1
# tensor([168,  14,   7])
# 1
# tensor([14,  7, 64])
# 1
# tensor([  7,  64, 145])
# 1
# tensor([ 64, 145, 182])
# 1
# tensor([145, 182,   8])
# 1
# tensor([182,   8, 191])
# 1
# tensor([  8, 191,  50])
# 1
# tensor([191,  50,  62])
# 1
# tensor([ 50,  62, 157])
# 1
# tensor([ 62, 157,   2])
# 1
# tensor([157,   2, 100])
# 1
# tensor([  2, 100,  91])
# 1
# tensor([100,  91, 114])
# 1
# tensor([ 91, 114, 175])
# 1
# tensor([114, 175, 140])
# 1
# tensor([175, 140,  96])
# 1
# tensor([140,  96, 170])
# 1
# tensor([ 96, 170, 128])
# 1
# tensor([170, 128,  40])
# 1
# tensor([128,  40,  57])
# 1
# tensor([ 40,  57, 131])
# 1
# tensor([ 57, 131,  52])
# 1
# tensor([131,  52, 147])
# 1
# tensor([ 52, 147, 186])
# 1
# tensor([147, 186,  82])
# 1
# tensor([186,  82, 180])
# 1
# tensor([ 82, 180, 123])
# 1
# tensor([180, 123, 176])
# 1
# tensor([123, 176, 180])
# 1
# tensor([176, 180,  56])
# 1
# tensor([180,  56, 148])
# 1
# tensor([ 56, 148, 135])
# 1
# tensor([148, 135, 174])
# 1
# tensor([135, 174,  67])
# 1
# tensor([174,  67,  81])
# 1
# tensor([ 67,  81, 185])
# 1
# tensor([ 81, 185,  31])
# 1
# tensor([185,  31,  19])
# 1
# tensor([ 31,  19, 149])
# 1
# tensor([ 19, 149, 167])
# 1
# tensor([149, 167, 124])
# 1
# tensor([167, 124,  26])
# 1
# tensor([124,  26, 159])
# 1
# tensor([ 26, 159,  96])
# 1
# tensor([159,  96, 162])
# 1
# tensor([ 96, 162,  61])
# 1
# tensor([162,  61,  96])
# 1
# tensor([ 61,  96, 121])
# 1
# tensor([ 96, 121,  83])
# 1
# tensor([121,  83, 190])
# 1
# tensor([ 83, 190, 110])
# 1
# tensor([190, 110,  58])
# 1
# tensor([110,  58, 101])
# 1
# tensor([ 58, 101, 180])
# 1
# tensor([101, 180, 103])
# 1
# tensor([180, 103,  49])
# 1
# tensor([103,  49, 117])
# 1
# tensor([ 49, 117,  46])
# 1
# tensor([117,  46,  59])
# 1
# tensor([46, 59, 76])
# 1
# tensor([59, 76,  3])
# 1
# tensor([ 76,   3, 146])
# 1
# tensor([  3, 146,  40])
# 1
# tensor([146,  40, 149])
# 1
# tensor([ 40, 149, 118])
# 1
# tensor([149, 118,  85])
# 1
# tensor([118,  85,   5])
# 1
# tensor([85,  5, 96])
# 1
# tensor([  5,  96, 180])
# 1
# tensor([ 96, 180, 158])
# 1
# tensor([180, 158, 104])
# 1
# tensor([158, 104,  10])
# 1
# tensor([104,  10,  96])
# 1
# tensor([ 10,  96, 180])
# 1
# tensor([ 96, 180, 189])
# 1
# tensor([180, 189, 187])
# 1
# tensor([189, 187, 165])
# 1
# tensor([187, 165, 177])
# 1
# tensor([165, 177,  54])
# 1
# tensor([177,  54,  43])
# 1
# tensor([ 54,  43, 166])
# 1
# tensor([ 43, 166,  79])
# 1
# tensor([166,  79,  94])
# 1
# tensor([ 79,  94, 180])
# 1
# tensor([ 94, 180, 192])
# 1
# tensor([180, 192,  49])
# 1
# tensor([192,  49, 117])
# 1
# tensor([ 49, 117, 151])
# 1
# tensor([117, 151, 171])
# 1
# tensor([151, 171, 108])
# 1
# tensor([171, 108, 119])
# 1
# tensor([108, 119, 144])
# 1
# tensor([119, 144,  76])
# 1
# tensor([144,  76, 152])
# 1
# tensor([ 76, 152,  71])
# 1
# tensor([152,  71,  18])
# 1
# tensor([71, 18, 87])
# 1
# tensor([18, 87, 15])
# 1
# tensor([ 87,  15, 125])
# 1
# tensor([ 15, 125,  73])
# 1
# tensor([125,  73, 117])
# 1
# tensor([ 73, 117, 161])
# 1
# tensor([117, 161, 109])
# 1
# tensor([161, 109,  99])
# 1
# tensor([109,  99,  35])
# 1
# tensor([ 99,  35, 180])
# 1
# tensor([ 35, 180, 115])
# 1
# tensor([180, 115,  39])
# 1
# tensor([115,  39, 111])
# 1
# tensor([ 39, 111,  96])
# 1
# tensor([111,  96, 122])
# 1
# tensor([ 96, 122,  30])
# 1
# tensor([122,  30, 133])
# 1
# tensor([ 30, 133,  55])
# 1
# tensor([133,  55,  16])
# 1
# tensor([55, 16, 45])
# 1
# tensor([16, 45, 40])
# 1
# tensor([ 45,  40, 180])
# 1
# tensor([ 40, 180, 173])
# 1
# tensor([180, 173,   0])
# 1
# tensor([173,   0,  65])
# 1
# tensor([  0,  65, 150])
# 1
# tensor([ 65, 150,  74])
# 1
# tensor([150,  74, 129])
# 1
# tensor([ 74, 129,  42])
# 1
# tensor([129,  42,  35])
# 1
# tensor([ 42,  35, 180])
# 1
# tensor([ 35, 180,  36])
# 1
# tensor([180,  36, 107])
# 1
# tensor([ 36, 107,   0])
# 1
# tensor([107,   0, 155])
# 1
# tensor([  0, 155,  40])
# 1
# tensor([155,  40,  68])
# 1
# tensor([40, 68, 23])
# 1
# tensor([ 68,  23, 180])
# 1
# tensor([ 23, 180,   9])
# 1
# tensor([180,   9,  38])
# 1
# tensor([ 9, 38, 53])
# 1
# tensor([ 38,  53, 117])
# 1
# tensor([ 53, 117,  60])
# 1
# tensor([117,  60,  90])
# 1
# tensor([ 60,  90, 129])
# 1
# tensor([ 90, 129,  20])
# 1
# tensor([129,  20,   3])
# 1
# tensor([20,  3, 77])
# 1
# tensor([ 3, 77, 40])
# 1
# tensor([ 77,  40, 130])
# 1
# tensor([ 40, 130,  35])
# 1
# tensor([130,  35, 126])
# 1
# tensor([ 35, 126,  22])
# 1
# tensor([126,  22,  33])
# 1
# tensor([22, 33, 95])
# 1
# tensor([ 33,  95, 172])
# 1
# tensor([ 95, 172, 177])
# 1
# tensor([172, 177,   6])
# 1
# tensor([177,   6,  40])
# 1
# tensor([  6,  40, 164])
# 1355.7016410827637
# 2
# tensor([ 92,  69, 180])
# 2
# tensor([ 69, 180, 179])
# 2
# tensor([180, 179,  80])
# 2
# tensor([179,  80,  66])
# 2
# tensor([ 80,  66, 141])
# 2
# tensor([ 66, 141, 163])
# 2
# tensor([141, 163,  72])
# 2
# tensor([163,  72,  29])
# 2
# tensor([72, 29, 85])
# 2
# tensor([29, 85, 97])
# 2
# tensor([85, 97, 24])
# 2
# tensor([ 97,  24, 168])
# 2
# tensor([ 24, 168, 134])
# 2
# tensor([168, 134,  80])
# 2
# tensor([134,  80,  34])
# 2
# tensor([ 80,  34, 180])
# 2
# tensor([ 34, 180,  12])
# 2
# tensor([180,  12,  40])
# 2
# tensor([12, 40, 27])
# 2
# tensor([40, 27, 44])
# 2
# tensor([ 27,  44, 137])
# 2
# tensor([ 44, 137,  47])
# 2
# tensor([137,  47, 183])
# 2
# tensor([ 47, 183,  41])
# 2
# tensor([183,  41,  25])
# 2
# tensor([ 41,  25, 184])
# 2
# tensor([ 25, 184,  40])
# 2
# tensor([184,  40,  17])
# 2
# tensor([40, 17, 11])
# 2
# tensor([ 17,  11, 143])
# 2
# tensor([ 11, 143, 138])
# 2
# tensor([143, 138,  80])
# 2
# tensor([138,  80,  66])
# 2
# tensor([ 80,  66, 154])
# 2
# tensor([ 66, 154,  48])
# 2
# tensor([154,  48,  84])
# 2
# tensor([ 48,  84, 186])
# 2
# tensor([ 84, 186,  47])
# 2
# tensor([186,  47, 183])
# 2
# tensor([ 47, 183, 178])
# 2
# tensor([183, 178,  40])
# 2
# tensor([178,  40, 153])
# 2
# tensor([ 40, 153, 132])
# 2
# tensor([153, 132,  86])
# 2
# tensor([132,  86, 117])
# 2
# tensor([ 86, 117,  37])
# 2
# tensor([117,  37,  13])
# 2
# tensor([37, 13, 49])
# 2
# tensor([ 13,  49, 142])
# 2
# tensor([ 49, 142, 193])
# 2
# tensor([142, 193, 102])
# 2
# tensor([193, 102, 181])
# 2
# tensor([102, 181,  40])
# 2
# tensor([181,  40,   1])
# 2
# tensor([40,  1,  4])
# 2
# tensor([ 1,  4, 35])
# 2
# tensor([  4,  35, 180])
# 2
# tensor([ 35, 180,  63])
# 2
# tensor([180,  63,  40])
# 2
# tensor([63, 40, 75])
# 2
# tensor([40, 75, 28])
# 2
# tensor([75, 28, 48])
# 2
# tensor([ 28,  48, 106])
# 2
# tensor([ 48, 106, 133])
# 2
# tensor([106, 133,  96])
# 2
# tensor([133,  96, 180])
# 2
# tensor([ 96, 180, 169])
# 2
# tensor([180, 169,  89])
# 2
# tensor([169,  89,  18])
# 2
# tensor([89, 18, 87])
# 2
# tensor([18, 87, 86])
# 2
# tensor([87, 86, 98])
# 2
# tensor([ 86,  98, 105])
# 2
# tensor([ 98, 105, 139])
# 2
# tensor([105, 139,  70])
# 2
# tensor([139,  70,  51])
# 2
# tensor([70, 51, 86])
# 2
# tensor([ 51,  86, 112])
# 2
# tensor([ 86, 112, 186])
# 2
# tensor([112, 186, 188])
# 2
# tensor([186, 188,  93])
# 2
# tensor([188,  93, 156])
# 2
# tensor([ 93, 156, 127])
# 2
# tensor([156, 127,  49])
# 2
# tensor([127,  49,  88])
# 2
# tensor([ 49,  88, 194])
# 2
# tensor([ 88, 194, 160])
# 2
# tensor([194, 160,  40])
# 2
# tensor([160,  40, 136])
# 2
# tensor([ 40, 136, 180])
# 2
# tensor([136, 180, 120])
# 2
# tensor([180, 120,  49])
# 2
# tensor([120,  49,  21])
# 2
# tensor([49, 21, 72])
# 2
# tensor([ 21,  72, 113])
# 2
# tensor([ 72, 113,  32])
# 2
# tensor([113,  32, 116])
# 2
# tensor([ 32, 116, 168])
# 2
# tensor([116, 168,  14])
# 2
# tensor([168,  14,   7])
# 2
# tensor([14,  7, 64])
# 2
# tensor([  7,  64, 145])
# 2
# tensor([ 64, 145, 182])
# 2
# tensor([145, 182,   8])
# 2
# tensor([182,   8, 191])
# 2
# tensor([  8, 191,  50])
# 2
# tensor([191,  50,  62])
# 2
# tensor([ 50,  62, 157])
# 2
# tensor([ 62, 157,   2])
# 2
# tensor([157,   2, 100])
# 2
# tensor([  2, 100,  91])
# 2
# tensor([100,  91, 114])
# 2
# tensor([ 91, 114, 175])
# 2
# tensor([114, 175, 140])
# 2
# tensor([175, 140,  96])
# 2
# tensor([140,  96, 170])
# 2
# tensor([ 96, 170, 128])
# 2
# tensor([170, 128,  40])
# 2
# tensor([128,  40,  57])
# 2
# tensor([ 40,  57, 131])
# 2
# tensor([ 57, 131,  52])
# 2
# tensor([131,  52, 147])
# 2
# tensor([ 52, 147, 186])
# 2
# tensor([147, 186,  82])
# 2
# tensor([186,  82, 180])
# 2
# tensor([ 82, 180, 123])
# 2
# tensor([180, 123, 176])
# 2
# tensor([123, 176, 180])
# 2
# tensor([176, 180,  56])
# 2
# tensor([180,  56, 148])
# 2
# tensor([ 56, 148, 135])
# 2
# tensor([148, 135, 174])
# 2
# tensor([135, 174,  67])
# 2
# tensor([174,  67,  81])
# 2
# tensor([ 67,  81, 185])
# 2
# tensor([ 81, 185,  31])
# 2
# tensor([185,  31,  19])
# 2
# tensor([ 31,  19, 149])
# 2
# tensor([ 19, 149, 167])
# 2
# tensor([149, 167, 124])
# 2
# tensor([167, 124,  26])
# 2
# tensor([124,  26, 159])
# 2
# tensor([ 26, 159,  96])
# 2
# tensor([159,  96, 162])
# 2
# tensor([ 96, 162,  61])
# 2
# tensor([162,  61,  96])
# 2
# tensor([ 61,  96, 121])
# 2
# tensor([ 96, 121,  83])
# 2
# tensor([121,  83, 190])
# 2
# tensor([ 83, 190, 110])
# 2
# tensor([190, 110,  58])
# 2
# tensor([110,  58, 101])
# 2
# tensor([ 58, 101, 180])
# 2
# tensor([101, 180, 103])
# 2
# tensor([180, 103,  49])
# 2
# tensor([103,  49, 117])
# 2
# tensor([ 49, 117,  46])
# 2
# tensor([117,  46,  59])
# 2
# tensor([46, 59, 76])
# 2
# tensor([59, 76,  3])
# 2
# tensor([ 76,   3, 146])
# 2
# tensor([  3, 146,  40])
# 2
# tensor([146,  40, 149])
# 2
# tensor([ 40, 149, 118])
# 2
# tensor([149, 118,  85])
# 2
# tensor([118,  85,   5])
# 2
# tensor([85,  5, 96])
# 2
# tensor([  5,  96, 180])
# 2
# tensor([ 96, 180, 158])
# 2
# tensor([180, 158, 104])
# 2
# tensor([158, 104,  10])
# 2
# tensor([104,  10,  96])
# 2
# tensor([ 10,  96, 180])
# 2
# tensor([ 96, 180, 189])
# 2
# tensor([180, 189, 187])
# 2
# tensor([189, 187, 165])
# 2
# tensor([187, 165, 177])
# 2
# tensor([165, 177,  54])
# 2
# tensor([177,  54,  43])
# 2
# tensor([ 54,  43, 166])
# 2
# tensor([ 43, 166,  79])
# 2
# tensor([166,  79,  94])
# 2
# tensor([ 79,  94, 180])
# 2
# tensor([ 94, 180, 192])
# 2
# tensor([180, 192,  49])
# 2
# tensor([192,  49, 117])
# 2
# tensor([ 49, 117, 151])
# 2
# tensor([117, 151, 171])
# 2
# tensor([151, 171, 108])
# 2
# tensor([171, 108, 119])
# 2
# tensor([108, 119, 144])
# 2
# tensor([119, 144,  76])
# 2
# tensor([144,  76, 152])
# 2
# tensor([ 76, 152,  71])
# 2
# tensor([152,  71,  18])
# 2
# tensor([71, 18, 87])
# 2
# tensor([18, 87, 15])
# 2
# tensor([ 87,  15, 125])
# 2
# tensor([ 15, 125,  73])
# 2
# tensor([125,  73, 117])
# 2
# tensor([ 73, 117, 161])
# 2
# tensor([117, 161, 109])
# 2
# tensor([161, 109,  99])
# 2
# tensor([109,  99,  35])
# 2
# tensor([ 99,  35, 180])
# 2
# tensor([ 35, 180, 115])
# 2
# tensor([180, 115,  39])
# 2
# tensor([115,  39, 111])
# 2
# tensor([ 39, 111,  96])
# 2
# tensor([111,  96, 122])
# 2
# tensor([ 96, 122,  30])
# 2
# tensor([122,  30, 133])
# 2
# tensor([ 30, 133,  55])
# 2
# tensor([133,  55,  16])
# 2
# tensor([55, 16, 45])
# 2
# tensor([16, 45, 40])
# 2
# tensor([ 45,  40, 180])
# 2
# tensor([ 40, 180, 173])
# 2
# tensor([180, 173,   0])
# 2
# tensor([173,   0,  65])
# 2
# tensor([  0,  65, 150])
# 2
# tensor([ 65, 150,  74])
# 2
# tensor([150,  74, 129])
# 2
# tensor([ 74, 129,  42])
# 2
# tensor([129,  42,  35])
# 2
# tensor([ 42,  35, 180])
# 2
# tensor([ 35, 180,  36])
# 2
# tensor([180,  36, 107])
# 2
# tensor([ 36, 107,   0])
# 2
# tensor([107,   0, 155])
# 2
# tensor([  0, 155,  40])
# 2
# tensor([155,  40,  68])
# 2
# tensor([40, 68, 23])
# 2
# tensor([ 68,  23, 180])
# 2
# tensor([ 23, 180,   9])
# 2
# tensor([180,   9,  38])
# 2
# tensor([ 9, 38, 53])
# 2
# tensor([ 38,  53, 117])
# 2
# tensor([ 53, 117,  60])
# 2
# tensor([117,  60,  90])
# 2
# tensor([ 60,  90, 129])
# 2
# tensor([ 90, 129,  20])
# 2
# tensor([129,  20,   3])
# 2
# tensor([20,  3, 77])
# 2
# tensor([ 3, 77, 40])
# 2
# tensor([ 77,  40, 130])
# 2
# tensor([ 40, 130,  35])
# 2
# tensor([130,  35, 126])
# 2
# tensor([ 35, 126,  22])
# 2
# tensor([126,  22,  33])
# 2
# tensor([22, 33, 95])
# 2
# tensor([ 33,  95, 172])
# 2
# tensor([ 95, 172, 177])
# 2
# tensor([172, 177,   6])
# 2
# tensor([177,   6,  40])
# 2
# tensor([  6,  40, 164])
# 1346.9038367271423
# 3
# tensor([ 92,  69, 180])
# 3
# tensor([ 69, 180, 179])
# 3
# tensor([180, 179,  80])
# 3
# tensor([179,  80,  66])
# 3
# tensor([ 80,  66, 141])
# 3
# tensor([ 66, 141, 163])
# 3
# tensor([141, 163,  72])
# 3
# tensor([163,  72,  29])
# 3
# tensor([72, 29, 85])
# 3
# tensor([29, 85, 97])
# 3
# tensor([85, 97, 24])
# 3
# tensor([ 97,  24, 168])
# 3
# tensor([ 24, 168, 134])
# 3
# tensor([168, 134,  80])
# 3
# tensor([134,  80,  34])
# 3
# tensor([ 80,  34, 180])
# 3
# tensor([ 34, 180,  12])
# 3
# tensor([180,  12,  40])
# 3
# tensor([12, 40, 27])
# 3
# tensor([40, 27, 44])
# 3
# tensor([ 27,  44, 137])
# 3
# tensor([ 44, 137,  47])
# 3
# tensor([137,  47, 183])
# 3
# tensor([ 47, 183,  41])
# 3
# tensor([183,  41,  25])
# 3
# tensor([ 41,  25, 184])
# 3
# tensor([ 25, 184,  40])
# 3
# tensor([184,  40,  17])
# 3
# tensor([40, 17, 11])
# 3
# tensor([ 17,  11, 143])
# 3
# tensor([ 11, 143, 138])
# 3
# tensor([143, 138,  80])
# 3
# tensor([138,  80,  66])
# 3
# tensor([ 80,  66, 154])
# 3
# tensor([ 66, 154,  48])
# 3
# tensor([154,  48,  84])
# 3
# tensor([ 48,  84, 186])
# 3
# tensor([ 84, 186,  47])
# 3
# tensor([186,  47, 183])
# 3
# tensor([ 47, 183, 178])
# 3
# tensor([183, 178,  40])
# 3
# tensor([178,  40, 153])
# 3
# tensor([ 40, 153, 132])
# 3
# tensor([153, 132,  86])
# 3
# tensor([132,  86, 117])
# 3
# tensor([ 86, 117,  37])
# 3
# tensor([117,  37,  13])
# 3
# tensor([37, 13, 49])
# 3
# tensor([ 13,  49, 142])
# 3
# tensor([ 49, 142, 193])
# 3
# tensor([142, 193, 102])
# 3
# tensor([193, 102, 181])
# 3
# tensor([102, 181,  40])
# 3
# tensor([181,  40,   1])
# 3
# tensor([40,  1,  4])
# 3
# tensor([ 1,  4, 35])
# 3
# tensor([  4,  35, 180])
# 3
# tensor([ 35, 180,  63])
# 3
# tensor([180,  63,  40])
# 3
# tensor([63, 40, 75])
# 3
# tensor([40, 75, 28])
# 3
# tensor([75, 28, 48])
# 3
# tensor([ 28,  48, 106])
# 3
# tensor([ 48, 106, 133])
# 3
# tensor([106, 133,  96])
# 3
# tensor([133,  96, 180])
# 3
# tensor([ 96, 180, 169])
# 3
# tensor([180, 169,  89])
# 3
# tensor([169,  89,  18])
# 3
# tensor([89, 18, 87])
# 3
# tensor([18, 87, 86])
# 3
# tensor([87, 86, 98])
# 3
# tensor([ 86,  98, 105])
# 3
# tensor([ 98, 105, 139])
# 3
# tensor([105, 139,  70])
# 3
# tensor([139,  70,  51])
# 3
# tensor([70, 51, 86])
# 3
# tensor([ 51,  86, 112])
# 3
# tensor([ 86, 112, 186])
# 3
# tensor([112, 186, 188])
# 3
# tensor([186, 188,  93])
# 3
# tensor([188,  93, 156])
# 3
# tensor([ 93, 156, 127])
# 3
# tensor([156, 127,  49])
# 3
# tensor([127,  49,  88])
# 3
# tensor([ 49,  88, 194])
# 3
# tensor([ 88, 194, 160])
# 3
# tensor([194, 160,  40])
# 3
# tensor([160,  40, 136])
# 3
# tensor([ 40, 136, 180])
# 3
# tensor([136, 180, 120])
# 3
# tensor([180, 120,  49])
# 3
# tensor([120,  49,  21])
# 3
# tensor([49, 21, 72])
# 3
# tensor([ 21,  72, 113])
# 3
# tensor([ 72, 113,  32])
# 3
# tensor([113,  32, 116])
# 3
# tensor([ 32, 116, 168])
# 3
# tensor([116, 168,  14])
# 3
# tensor([168,  14,   7])
# 3
# tensor([14,  7, 64])
# 3
# tensor([  7,  64, 145])
# 3
# tensor([ 64, 145, 182])
# 3
# tensor([145, 182,   8])
# 3
# tensor([182,   8, 191])
# 3
# tensor([  8, 191,  50])
# 3
# tensor([191,  50,  62])
# 3
# tensor([ 50,  62, 157])
# 3
# tensor([ 62, 157,   2])
# 3
# tensor([157,   2, 100])
# 3
# tensor([  2, 100,  91])
# 3
# tensor([100,  91, 114])
# 3
# tensor([ 91, 114, 175])
# 3
# tensor([114, 175, 140])
# 3
# tensor([175, 140,  96])
# 3
# tensor([140,  96, 170])
# 3
# tensor([ 96, 170, 128])
# 3
# tensor([170, 128,  40])
# 3
# tensor([128,  40,  57])
# 3
# tensor([ 40,  57, 131])
# 3
# tensor([ 57, 131,  52])
# 3
# tensor([131,  52, 147])
# 3
# tensor([ 52, 147, 186])
# 3
# tensor([147, 186,  82])
# 3
# tensor([186,  82, 180])
# 3
# tensor([ 82, 180, 123])
# 3
# tensor([180, 123, 176])
# 3
# tensor([123, 176, 180])
# 3
# tensor([176, 180,  56])
# 3
# tensor([180,  56, 148])
# 3
# tensor([ 56, 148, 135])
# 3
# tensor([148, 135, 174])
# 3
# tensor([135, 174,  67])
# 3
# tensor([174,  67,  81])
# 3
# tensor([ 67,  81, 185])
# 3
# tensor([ 81, 185,  31])
# 3
# tensor([185,  31,  19])
# 3
# tensor([ 31,  19, 149])
# 3
# tensor([ 19, 149, 167])
# 3
# tensor([149, 167, 124])
# 3
# tensor([167, 124,  26])
# 3
# tensor([124,  26, 159])
# 3
# tensor([ 26, 159,  96])
# 3
# tensor([159,  96, 162])
# 3
# tensor([ 96, 162,  61])
# 3
# tensor([162,  61,  96])
# 3
# tensor([ 61,  96, 121])
# 3
# tensor([ 96, 121,  83])
# 3
# tensor([121,  83, 190])
# 3
# tensor([ 83, 190, 110])
# 3
# tensor([190, 110,  58])
# 3
# tensor([110,  58, 101])
# 3
# tensor([ 58, 101, 180])
# 3
# tensor([101, 180, 103])
# 3
# tensor([180, 103,  49])
# 3
# tensor([103,  49, 117])
# 3
# tensor([ 49, 117,  46])
# 3
# tensor([117,  46,  59])
# 3
# tensor([46, 59, 76])
# 3
# tensor([59, 76,  3])
# 3
# tensor([ 76,   3, 146])
# 3
# tensor([  3, 146,  40])
# 3
# tensor([146,  40, 149])
# 3
# tensor([ 40, 149, 118])
# 3
# tensor([149, 118,  85])
# 3
# tensor([118,  85,   5])
# 3
# tensor([85,  5, 96])
# 3
# tensor([  5,  96, 180])
# 3
# tensor([ 96, 180, 158])
# 3
# tensor([180, 158, 104])
# 3
# tensor([158, 104,  10])
# 3
# tensor([104,  10,  96])
# 3
# tensor([ 10,  96, 180])
# 3
# tensor([ 96, 180, 189])
# 3
# tensor([180, 189, 187])
# 3
# tensor([189, 187, 165])
# 3
# tensor([187, 165, 177])
# 3
# tensor([165, 177,  54])
# 3
# tensor([177,  54,  43])
# 3
# tensor([ 54,  43, 166])
# 3
# tensor([ 43, 166,  79])
# 3
# tensor([166,  79,  94])
# 3
# tensor([ 79,  94, 180])
# 3
# tensor([ 94, 180, 192])
# 3
# tensor([180, 192,  49])
# 3
# tensor([192,  49, 117])
# 3
# tensor([ 49, 117, 151])
# 3
# tensor([117, 151, 171])
# 3
# tensor([151, 171, 108])
# 3
# tensor([171, 108, 119])
# 3
# tensor([108, 119, 144])
# 3
# tensor([119, 144,  76])
# 3
# tensor([144,  76, 152])
# 3
# tensor([ 76, 152,  71])
# 3
# tensor([152,  71,  18])
# 3
# tensor([71, 18, 87])
# 3
# tensor([18, 87, 15])
# 3
# tensor([ 87,  15, 125])
# 3
# tensor([ 15, 125,  73])
# 3
# tensor([125,  73, 117])
# 3
# tensor([ 73, 117, 161])
# 3
# tensor([117, 161, 109])
# 3
# tensor([161, 109,  99])
# 3
# tensor([109,  99,  35])
# 3
# tensor([ 99,  35, 180])
# 3
# tensor([ 35, 180, 115])
# 3
# tensor([180, 115,  39])
# 3
# tensor([115,  39, 111])
# 3
# tensor([ 39, 111,  96])
# 3
# tensor([111,  96, 122])
# 3
# tensor([ 96, 122,  30])
# 3
# tensor([122,  30, 133])
# 3
# tensor([ 30, 133,  55])
# 3
# tensor([133,  55,  16])
# 3
# tensor([55, 16, 45])
# 3
# tensor([16, 45, 40])
# 3
# tensor([ 45,  40, 180])
# 3
# tensor([ 40, 180, 173])
# 3
# tensor([180, 173,   0])
# 3
# tensor([173,   0,  65])
# 3
# tensor([  0,  65, 150])
# 3
# tensor([ 65, 150,  74])
# 3
# tensor([150,  74, 129])
# 3
# tensor([ 74, 129,  42])
# 3
# tensor([129,  42,  35])
# 3
# tensor([ 42,  35, 180])
# 3
# tensor([ 35, 180,  36])
# 3
# tensor([180,  36, 107])
# 3
# tensor([ 36, 107,   0])
# 3
# tensor([107,   0, 155])
# 3
# tensor([  0, 155,  40])
# 3
# tensor([155,  40,  68])
# 3
# tensor([40, 68, 23])
# 3
# tensor([ 68,  23, 180])
# 3
# tensor([ 23, 180,   9])
# 3
# tensor([180,   9,  38])
# 3
# tensor([ 9, 38, 53])
# 3
# tensor([ 38,  53, 117])
# 3
# tensor([ 53, 117,  60])
# 3
# tensor([117,  60,  90])
# 3
# tensor([ 60,  90, 129])
# 3
# tensor([ 90, 129,  20])
# 3
# tensor([129,  20,   3])
# 3
# tensor([20,  3, 77])
# 3
# tensor([ 3, 77, 40])
# 3
# tensor([ 77,  40, 130])
# 3
# tensor([ 40, 130,  35])
# 3
# tensor([130,  35, 126])
# 3
# tensor([ 35, 126,  22])
# 3
# tensor([126,  22,  33])
# 3
# tensor([22, 33, 95])
# 3
# tensor([ 33,  95, 172])
# 3
# tensor([ 95, 172, 177])
# 3
# tensor([172, 177,   6])
# 3
# tensor([177,   6,  40])
# 3
# tensor([  6,  40, 164])
# 1338.2313904762268
# 4
# tensor([ 92,  69, 180])
# 4
# tensor([ 69, 180, 179])
# 4
# tensor([180, 179,  80])
# 4
# tensor([179,  80,  66])
# 4
# tensor([ 80,  66, 141])
# 4
# tensor([ 66, 141, 163])
# 4
# tensor([141, 163,  72])
# 4
# tensor([163,  72,  29])
# 4
# tensor([72, 29, 85])
# 4
# tensor([29, 85, 97])
# 4
# tensor([85, 97, 24])
# 4
# tensor([ 97,  24, 168])
# 4
# tensor([ 24, 168, 134])
# 4
# tensor([168, 134,  80])
# 4
# tensor([134,  80,  34])
# 4
# tensor([ 80,  34, 180])
# 4
# tensor([ 34, 180,  12])
# 4
# tensor([180,  12,  40])
# 4
# tensor([12, 40, 27])
# 4
# tensor([40, 27, 44])
# 4
# tensor([ 27,  44, 137])
# 4
# tensor([ 44, 137,  47])
# 4
# tensor([137,  47, 183])
# 4
# tensor([ 47, 183,  41])
# 4
# tensor([183,  41,  25])
# 4
# tensor([ 41,  25, 184])
# 4
# tensor([ 25, 184,  40])
# 4
# tensor([184,  40,  17])
# 4
# tensor([40, 17, 11])
# 4
# tensor([ 17,  11, 143])
# 4
# tensor([ 11, 143, 138])
# 4
# tensor([143, 138,  80])
# 4
# tensor([138,  80,  66])
# 4
# tensor([ 80,  66, 154])
# 4
# tensor([ 66, 154,  48])
# 4
# tensor([154,  48,  84])
# 4
# tensor([ 48,  84, 186])
# 4
# tensor([ 84, 186,  47])
# 4
# tensor([186,  47, 183])
# 4
# tensor([ 47, 183, 178])
# 4
# tensor([183, 178,  40])
# 4
# tensor([178,  40, 153])
# 4
# tensor([ 40, 153, 132])
# 4
# tensor([153, 132,  86])
# 4
# tensor([132,  86, 117])
# 4
# tensor([ 86, 117,  37])
# 4
# tensor([117,  37,  13])
# 4
# tensor([37, 13, 49])
# 4
# tensor([ 13,  49, 142])
# 4
# tensor([ 49, 142, 193])
# 4
# tensor([142, 193, 102])
# 4
# tensor([193, 102, 181])
# 4
# tensor([102, 181,  40])
# 4
# tensor([181,  40,   1])
# 4
# tensor([40,  1,  4])
# 4
# tensor([ 1,  4, 35])
# 4
# tensor([  4,  35, 180])
# 4
# tensor([ 35, 180,  63])
# 4
# tensor([180,  63,  40])
# 4
# tensor([63, 40, 75])
# 4
# tensor([40, 75, 28])
# 4
# tensor([75, 28, 48])
# 4
# tensor([ 28,  48, 106])
# 4
# tensor([ 48, 106, 133])
# 4
# tensor([106, 133,  96])
# 4
# tensor([133,  96, 180])
# 4
# tensor([ 96, 180, 169])
# 4
# tensor([180, 169,  89])
# 4
# tensor([169,  89,  18])
# 4
# tensor([89, 18, 87])
# 4
# tensor([18, 87, 86])
# 4
# tensor([87, 86, 98])
# 4
# tensor([ 86,  98, 105])
# 4
# tensor([ 98, 105, 139])
# 4
# tensor([105, 139,  70])
# 4
# tensor([139,  70,  51])
# 4
# tensor([70, 51, 86])
# 4
# tensor([ 51,  86, 112])
# 4
# tensor([ 86, 112, 186])
# 4
# tensor([112, 186, 188])
# 4
# tensor([186, 188,  93])
# 4
# tensor([188,  93, 156])
# 4
# tensor([ 93, 156, 127])
# 4
# tensor([156, 127,  49])
# 4
# tensor([127,  49,  88])
# 4
# tensor([ 49,  88, 194])
# 4
# tensor([ 88, 194, 160])
# 4
# tensor([194, 160,  40])
# 4
# tensor([160,  40, 136])
# 4
# tensor([ 40, 136, 180])
# 4
# tensor([136, 180, 120])
# 4
# tensor([180, 120,  49])
# 4
# tensor([120,  49,  21])
# 4
# tensor([49, 21, 72])
# 4
# tensor([ 21,  72, 113])
# 4
# tensor([ 72, 113,  32])
# 4
# tensor([113,  32, 116])
# 4
# tensor([ 32, 116, 168])
# 4
# tensor([116, 168,  14])
# 4
# tensor([168,  14,   7])
# 4
# tensor([14,  7, 64])
# 4
# tensor([  7,  64, 145])
# 4
# tensor([ 64, 145, 182])
# 4
# tensor([145, 182,   8])
# 4
# tensor([182,   8, 191])
# 4
# tensor([  8, 191,  50])
# 4
# tensor([191,  50,  62])
# 4
# tensor([ 50,  62, 157])
# 4
# tensor([ 62, 157,   2])
# 4
# tensor([157,   2, 100])
# 4
# tensor([  2, 100,  91])
# 4
# tensor([100,  91, 114])
# 4
# tensor([ 91, 114, 175])
# 4
# tensor([114, 175, 140])
# 4
# tensor([175, 140,  96])
# 4
# tensor([140,  96, 170])
# 4
# tensor([ 96, 170, 128])
# 4
# tensor([170, 128,  40])
# 4
# tensor([128,  40,  57])
# 4
# tensor([ 40,  57, 131])
# 4
# tensor([ 57, 131,  52])
# 4
# tensor([131,  52, 147])
# 4
# tensor([ 52, 147, 186])
# 4
# tensor([147, 186,  82])
# 4
# tensor([186,  82, 180])
# 4
# tensor([ 82, 180, 123])
# 4
# tensor([180, 123, 176])
# 4
# tensor([123, 176, 180])
# 4
# tensor([176, 180,  56])
# 4
# tensor([180,  56, 148])
# 4
# tensor([ 56, 148, 135])
# 4
# tensor([148, 135, 174])
# 4
# tensor([135, 174,  67])
# 4
# tensor([174,  67,  81])
# 4
# tensor([ 67,  81, 185])
# 4
# tensor([ 81, 185,  31])
# 4
# tensor([185,  31,  19])
# 4
# tensor([ 31,  19, 149])
# 4
# tensor([ 19, 149, 167])
# 4
# tensor([149, 167, 124])
# 4
# tensor([167, 124,  26])
# 4
# tensor([124,  26, 159])
# 4
# tensor([ 26, 159,  96])
# 4
# tensor([159,  96, 162])
# 4
# tensor([ 96, 162,  61])
# 4
# tensor([162,  61,  96])
# 4
# tensor([ 61,  96, 121])
# 4
# tensor([ 96, 121,  83])
# 4
# tensor([121,  83, 190])
# 4
# tensor([ 83, 190, 110])
# 4
# tensor([190, 110,  58])
# 4
# tensor([110,  58, 101])
# 4
# tensor([ 58, 101, 180])
# 4
# tensor([101, 180, 103])
# 4
# tensor([180, 103,  49])
# 4
# tensor([103,  49, 117])
# 4
# tensor([ 49, 117,  46])
# 4
# tensor([117,  46,  59])
# 4
# tensor([46, 59, 76])
# 4
# tensor([59, 76,  3])
# 4
# tensor([ 76,   3, 146])
# 4
# tensor([  3, 146,  40])
# 4
# tensor([146,  40, 149])
# 4
# tensor([ 40, 149, 118])
# 4
# tensor([149, 118,  85])
# 4
# tensor([118,  85,   5])
# 4
# tensor([85,  5, 96])
# 4
# tensor([  5,  96, 180])
# 4
# tensor([ 96, 180, 158])
# 4
# tensor([180, 158, 104])
# 4
# tensor([158, 104,  10])
# 4
# tensor([104,  10,  96])
# 4
# tensor([ 10,  96, 180])
# 4
# tensor([ 96, 180, 189])
# 4
# tensor([180, 189, 187])
# 4
# tensor([189, 187, 165])
# 4
# tensor([187, 165, 177])
# 4
# tensor([165, 177,  54])
# 4
# tensor([177,  54,  43])
# 4
# tensor([ 54,  43, 166])
# 4
# tensor([ 43, 166,  79])
# 4
# tensor([166,  79,  94])
# 4
# tensor([ 79,  94, 180])
# 4
# tensor([ 94, 180, 192])
# 4
# tensor([180, 192,  49])
# 4
# tensor([192,  49, 117])
# 4
# tensor([ 49, 117, 151])
# 4
# tensor([117, 151, 171])
# 4
# tensor([151, 171, 108])
# 4
# tensor([171, 108, 119])
# 4
# tensor([108, 119, 144])
# 4
# tensor([119, 144,  76])
# 4
# tensor([144,  76, 152])
# 4
# tensor([ 76, 152,  71])
# 4
# tensor([152,  71,  18])
# 4
# tensor([71, 18, 87])
# 4
# tensor([18, 87, 15])
# 4
# tensor([ 87,  15, 125])
# 4
# tensor([ 15, 125,  73])
# 4
# tensor([125,  73, 117])
# 4
# tensor([ 73, 117, 161])
# 4
# tensor([117, 161, 109])
# 4
# tensor([161, 109,  99])
# 4
# tensor([109,  99,  35])
# 4
# tensor([ 99,  35, 180])
# 4
# tensor([ 35, 180, 115])
# 4
# tensor([180, 115,  39])
# 4
# tensor([115,  39, 111])
# 4
# tensor([ 39, 111,  96])
# 4
# tensor([111,  96, 122])
# 4
# tensor([ 96, 122,  30])
# 4
# tensor([122,  30, 133])
# 4
# tensor([ 30, 133,  55])
# 4
# tensor([133,  55,  16])
# 4
# tensor([55, 16, 45])
# 4
# tensor([16, 45, 40])
# 4
# tensor([ 45,  40, 180])
# 4
# tensor([ 40, 180, 173])
# 4
# tensor([180, 173,   0])
# 4
# tensor([173,   0,  65])
# 4
# tensor([  0,  65, 150])
# 4
# tensor([ 65, 150,  74])
# 4
# tensor([150,  74, 129])
# 4
# tensor([ 74, 129,  42])
# 4
# tensor([129,  42,  35])
# 4
# tensor([ 42,  35, 180])
# 4
# tensor([ 35, 180,  36])
# 4
# tensor([180,  36, 107])
# 4
# tensor([ 36, 107,   0])
# 4
# tensor([107,   0, 155])
# 4
# tensor([  0, 155,  40])
# 4
# tensor([155,  40,  68])
# 4
# tensor([40, 68, 23])
# 4
# tensor([ 68,  23, 180])
# 4
# tensor([ 23, 180,   9])
# 4
# tensor([180,   9,  38])
# 4
# tensor([ 9, 38, 53])
# 4
# tensor([ 38,  53, 117])
# 4
# tensor([ 53, 117,  60])
# 4
# tensor([117,  60,  90])
# 4
# tensor([ 60,  90, 129])
# 4
# tensor([ 90, 129,  20])
# 4
# tensor([129,  20,   3])
# 4
# tensor([20,  3, 77])
# 4
# tensor([ 3, 77, 40])
# 4
# tensor([ 77,  40, 130])
# 4
# tensor([ 40, 130,  35])
# 4
# tensor([130,  35, 126])
# 4
# tensor([ 35, 126,  22])
# 4
# tensor([126,  22,  33])
# 4
# tensor([22, 33, 95])
# 4
# tensor([ 33,  95, 172])
# 4
# tensor([ 95, 172, 177])
# 4
# tensor([172, 177,   6])
# 4
# tensor([177,   6,  40])
# 4
# tensor([  6,  40, 164])
# 1329.6734294891357
# 5
# tensor([ 92,  69, 180])
# 5
# tensor([ 69, 180, 179])
# 5
# tensor([180, 179,  80])
# 5
# tensor([179,  80,  66])
# 5
# tensor([ 80,  66, 141])
# 5
# tensor([ 66, 141, 163])
# 5
# tensor([141, 163,  72])
# 5
# tensor([163,  72,  29])
# 5
# tensor([72, 29, 85])
# 5
# tensor([29, 85, 97])
# 5
# tensor([85, 97, 24])
# 5
# tensor([ 97,  24, 168])
# 5
# tensor([ 24, 168, 134])
# 5
# tensor([168, 134,  80])
# 5
# tensor([134,  80,  34])
# 5
# tensor([ 80,  34, 180])
# 5
# tensor([ 34, 180,  12])
# 5
# tensor([180,  12,  40])
# 5
# tensor([12, 40, 27])
# 5
# tensor([40, 27, 44])
# 5
# tensor([ 27,  44, 137])
# 5
# tensor([ 44, 137,  47])
# 5
# tensor([137,  47, 183])
# 5
# tensor([ 47, 183,  41])
# 5
# tensor([183,  41,  25])
# 5
# tensor([ 41,  25, 184])
# 5
# tensor([ 25, 184,  40])
# 5
# tensor([184,  40,  17])
# 5
# tensor([40, 17, 11])
# 5
# tensor([ 17,  11, 143])
# 5
# tensor([ 11, 143, 138])
# 5
# tensor([143, 138,  80])
# 5
# tensor([138,  80,  66])
# 5
# tensor([ 80,  66, 154])
# 5
# tensor([ 66, 154,  48])
# 5
# tensor([154,  48,  84])
# 5
# tensor([ 48,  84, 186])
# 5
# tensor([ 84, 186,  47])
# 5
# tensor([186,  47, 183])
# 5
# tensor([ 47, 183, 178])
# 5
# tensor([183, 178,  40])
# 5
# tensor([178,  40, 153])
# 5
# tensor([ 40, 153, 132])
# 5
# tensor([153, 132,  86])
# 5
# tensor([132,  86, 117])
# 5
# tensor([ 86, 117,  37])
# 5
# tensor([117,  37,  13])
# 5
# tensor([37, 13, 49])
# 5
# tensor([ 13,  49, 142])
# 5
# tensor([ 49, 142, 193])
# 5
# tensor([142, 193, 102])
# 5
# tensor([193, 102, 181])
# 5
# tensor([102, 181,  40])
# 5
# tensor([181,  40,   1])
# 5
# tensor([40,  1,  4])
# 5
# tensor([ 1,  4, 35])
# 5
# tensor([  4,  35, 180])
# 5
# tensor([ 35, 180,  63])
# 5
# tensor([180,  63,  40])
# 5
# tensor([63, 40, 75])
# 5
# tensor([40, 75, 28])
# 5
# tensor([75, 28, 48])
# 5
# tensor([ 28,  48, 106])
# 5
# tensor([ 48, 106, 133])
# 5
# tensor([106, 133,  96])
# 5
# tensor([133,  96, 180])
# 5
# tensor([ 96, 180, 169])
# 5
# tensor([180, 169,  89])
# 5
# tensor([169,  89,  18])
# 5
# tensor([89, 18, 87])
# 5
# tensor([18, 87, 86])
# 5
# tensor([87, 86, 98])
# 5
# tensor([ 86,  98, 105])
# 5
# tensor([ 98, 105, 139])
# 5
# tensor([105, 139,  70])
# 5
# tensor([139,  70,  51])
# 5
# tensor([70, 51, 86])
# 5
# tensor([ 51,  86, 112])
# 5
# tensor([ 86, 112, 186])
# 5
# tensor([112, 186, 188])
# 5
# tensor([186, 188,  93])
# 5
# tensor([188,  93, 156])
# 5
# tensor([ 93, 156, 127])
# 5
# tensor([156, 127,  49])
# 5
# tensor([127,  49,  88])
# 5
# tensor([ 49,  88, 194])
# 5
# tensor([ 88, 194, 160])
# 5
# tensor([194, 160,  40])
# 5
# tensor([160,  40, 136])
# 5
# tensor([ 40, 136, 180])
# 5
# tensor([136, 180, 120])
# 5
# tensor([180, 120,  49])
# 5
# tensor([120,  49,  21])
# 5
# tensor([49, 21, 72])
# 5
# tensor([ 21,  72, 113])
# 5
# tensor([ 72, 113,  32])
# 5
# tensor([113,  32, 116])
# 5
# tensor([ 32, 116, 168])
# 5
# tensor([116, 168,  14])
# 5
# tensor([168,  14,   7])
# 5
# tensor([14,  7, 64])
# 5
# tensor([  7,  64, 145])
# 5
# tensor([ 64, 145, 182])
# 5
# tensor([145, 182,   8])
# 5
# tensor([182,   8, 191])
# 5
# tensor([  8, 191,  50])
# 5
# tensor([191,  50,  62])
# 5
# tensor([ 50,  62, 157])
# 5
# tensor([ 62, 157,   2])
# 5
# tensor([157,   2, 100])
# 5
# tensor([  2, 100,  91])
# 5
# tensor([100,  91, 114])
# 5
# tensor([ 91, 114, 175])
# 5
# tensor([114, 175, 140])
# 5
# tensor([175, 140,  96])
# 5
# tensor([140,  96, 170])
# 5
# tensor([ 96, 170, 128])
# 5
# tensor([170, 128,  40])
# 5
# tensor([128,  40,  57])
# 5
# tensor([ 40,  57, 131])
# 5
# tensor([ 57, 131,  52])
# 5
# tensor([131,  52, 147])
# 5
# tensor([ 52, 147, 186])
# 5
# tensor([147, 186,  82])
# 5
# tensor([186,  82, 180])
# 5
# tensor([ 82, 180, 123])
# 5
# tensor([180, 123, 176])
# 5
# tensor([123, 176, 180])
# 5
# tensor([176, 180,  56])
# 5
# tensor([180,  56, 148])
# 5
# tensor([ 56, 148, 135])
# 5
# tensor([148, 135, 174])
# 5
# tensor([135, 174,  67])
# 5
# tensor([174,  67,  81])
# 5
# tensor([ 67,  81, 185])
# 5
# tensor([ 81, 185,  31])
# 5
# tensor([185,  31,  19])
# 5
# tensor([ 31,  19, 149])
# 5
# tensor([ 19, 149, 167])
# 5
# tensor([149, 167, 124])
# 5
# tensor([167, 124,  26])
# 5
# tensor([124,  26, 159])
# 5
# tensor([ 26, 159,  96])
# 5
# tensor([159,  96, 162])
# 5
# tensor([ 96, 162,  61])
# 5
# tensor([162,  61,  96])
# 5
# tensor([ 61,  96, 121])
# 5
# tensor([ 96, 121,  83])
# 5
# tensor([121,  83, 190])
# 5
# tensor([ 83, 190, 110])
# 5
# tensor([190, 110,  58])
# 5
# tensor([110,  58, 101])
# 5
# tensor([ 58, 101, 180])
# 5
# tensor([101, 180, 103])
# 5
# tensor([180, 103,  49])
# 5
# tensor([103,  49, 117])
# 5
# tensor([ 49, 117,  46])
# 5
# tensor([117,  46,  59])
# 5
# tensor([46, 59, 76])
# 5
# tensor([59, 76,  3])
# 5
# tensor([ 76,   3, 146])
# 5
# tensor([  3, 146,  40])
# 5
# tensor([146,  40, 149])
# 5
# tensor([ 40, 149, 118])
# 5
# tensor([149, 118,  85])
# 5
# tensor([118,  85,   5])
# 5
# tensor([85,  5, 96])
# 5
# tensor([  5,  96, 180])
# 5
# tensor([ 96, 180, 158])
# 5
# tensor([180, 158, 104])
# 5
# tensor([158, 104,  10])
# 5
# tensor([104,  10,  96])
# 5
# tensor([ 10,  96, 180])
# 5
# tensor([ 96, 180, 189])
# 5
# tensor([180, 189, 187])
# 5
# tensor([189, 187, 165])
# 5
# tensor([187, 165, 177])
# 5
# tensor([165, 177,  54])
# 5
# tensor([177,  54,  43])
# 5
# tensor([ 54,  43, 166])
# 5
# tensor([ 43, 166,  79])
# 5
# tensor([166,  79,  94])
# 5
# tensor([ 79,  94, 180])
# 5
# tensor([ 94, 180, 192])
# 5
# tensor([180, 192,  49])
# 5
# tensor([192,  49, 117])
# 5
# tensor([ 49, 117, 151])
# 5
# tensor([117, 151, 171])
# 5
# tensor([151, 171, 108])
# 5
# tensor([171, 108, 119])
# 5
# tensor([108, 119, 144])
# 5
# tensor([119, 144,  76])
# 5
# tensor([144,  76, 152])
# 5
# tensor([ 76, 152,  71])
# 5
# tensor([152,  71,  18])
# 5
# tensor([71, 18, 87])
# 5
# tensor([18, 87, 15])
# 5
# tensor([ 87,  15, 125])
# 5
# tensor([ 15, 125,  73])
# 5
# tensor([125,  73, 117])
# 5
# tensor([ 73, 117, 161])
# 5
# tensor([117, 161, 109])
# 5
# tensor([161, 109,  99])
# 5
# tensor([109,  99,  35])
# 5
# tensor([ 99,  35, 180])
# 5
# tensor([ 35, 180, 115])
# 5
# tensor([180, 115,  39])
# 5
# tensor([115,  39, 111])
# 5
# tensor([ 39, 111,  96])
# 5
# tensor([111,  96, 122])
# 5
# tensor([ 96, 122,  30])
# 5
# tensor([122,  30, 133])
# 5
# tensor([ 30, 133,  55])
# 5
# tensor([133,  55,  16])
# 5
# tensor([55, 16, 45])
# 5
# tensor([16, 45, 40])
# 5
# tensor([ 45,  40, 180])
# 5
# tensor([ 40, 180, 173])
# 5
# tensor([180, 173,   0])
# 5
# tensor([173,   0,  65])
# 5
# tensor([  0,  65, 150])
# 5
# tensor([ 65, 150,  74])
# 5
# tensor([150,  74, 129])
# 5
# tensor([ 74, 129,  42])
# 5
# tensor([129,  42,  35])
# 5
# tensor([ 42,  35, 180])
# 5
# tensor([ 35, 180,  36])
# 5
# tensor([180,  36, 107])
# 5
# tensor([ 36, 107,   0])
# 5
# tensor([107,   0, 155])
# 5
# tensor([  0, 155,  40])
# 5
# tensor([155,  40,  68])
# 5
# tensor([40, 68, 23])
# 5
# tensor([ 68,  23, 180])
# 5
# tensor([ 23, 180,   9])
# 5
# tensor([180,   9,  38])
# 5
# tensor([ 9, 38, 53])
# 5
# tensor([ 38,  53, 117])
# 5
# tensor([ 53, 117,  60])
# 5
# tensor([117,  60,  90])
# 5
# tensor([ 60,  90, 129])
# 5
# tensor([ 90, 129,  20])
# 5
# tensor([129,  20,   3])
# 5
# tensor([20,  3, 77])
# 5
# tensor([ 3, 77, 40])
# 5
# tensor([ 77,  40, 130])
# 5
# tensor([ 40, 130,  35])
# 5
# tensor([130,  35, 126])
# 5
# tensor([ 35, 126,  22])
# 5
# tensor([126,  22,  33])
# 5
# tensor([22, 33, 95])
# 5
# tensor([ 33,  95, 172])
# 5
# tensor([ 95, 172, 177])
# 5
# tensor([172, 177,   6])
# 5
# tensor([177,   6,  40])
# 5
# tensor([  6,  40, 164])
# 1321.2255024909973
# 6
# tensor([ 92,  69, 180])
# 6
# tensor([ 69, 180, 179])
# 6
# tensor([180, 179,  80])
# 6
# tensor([179,  80,  66])
# 6
# tensor([ 80,  66, 141])
# 6
# tensor([ 66, 141, 163])
# 6
# tensor([141, 163,  72])
# 6
# tensor([163,  72,  29])
# 6
# tensor([72, 29, 85])
# 6
# tensor([29, 85, 97])
# 6
# tensor([85, 97, 24])
# 6
# tensor([ 97,  24, 168])
# 6
# tensor([ 24, 168, 134])
# 6
# tensor([168, 134,  80])
# 6
# tensor([134,  80,  34])
# 6
# tensor([ 80,  34, 180])
# 6
# tensor([ 34, 180,  12])
# 6
# tensor([180,  12,  40])
# 6
# tensor([12, 40, 27])
# 6
# tensor([40, 27, 44])
# 6
# tensor([ 27,  44, 137])
# 6
# tensor([ 44, 137,  47])
# 6
# tensor([137,  47, 183])
# 6
# tensor([ 47, 183,  41])
# 6
# tensor([183,  41,  25])
# 6
# tensor([ 41,  25, 184])
# 6
# tensor([ 25, 184,  40])
# 6
# tensor([184,  40,  17])
# 6
# tensor([40, 17, 11])
# 6
# tensor([ 17,  11, 143])
# 6
# tensor([ 11, 143, 138])
# 6
# tensor([143, 138,  80])
# 6
# tensor([138,  80,  66])
# 6
# tensor([ 80,  66, 154])
# 6
# tensor([ 66, 154,  48])
# 6
# tensor([154,  48,  84])
# 6
# tensor([ 48,  84, 186])
# 6
# tensor([ 84, 186,  47])
# 6
# tensor([186,  47, 183])
# 6
# tensor([ 47, 183, 178])
# 6
# tensor([183, 178,  40])
# 6
# tensor([178,  40, 153])
# 6
# tensor([ 40, 153, 132])
# 6
# tensor([153, 132,  86])
# 6
# tensor([132,  86, 117])
# 6
# tensor([ 86, 117,  37])
# 6
# tensor([117,  37,  13])
# 6
# tensor([37, 13, 49])
# 6
# tensor([ 13,  49, 142])
# 6
# tensor([ 49, 142, 193])
# 6
# tensor([142, 193, 102])
# 6
# tensor([193, 102, 181])
# 6
# tensor([102, 181,  40])
# 6
# tensor([181,  40,   1])
# 6
# tensor([40,  1,  4])
# 6
# tensor([ 1,  4, 35])
# 6
# tensor([  4,  35, 180])
# 6
# tensor([ 35, 180,  63])
# 6
# tensor([180,  63,  40])
# 6
# tensor([63, 40, 75])
# 6
# tensor([40, 75, 28])
# 6
# tensor([75, 28, 48])
# 6
# tensor([ 28,  48, 106])
# 6
# tensor([ 48, 106, 133])
# 6
# tensor([106, 133,  96])
# 6
# tensor([133,  96, 180])
# 6
# tensor([ 96, 180, 169])
# 6
# tensor([180, 169,  89])
# 6
# tensor([169,  89,  18])
# 6
# tensor([89, 18, 87])
# 6
# tensor([18, 87, 86])
# 6
# tensor([87, 86, 98])
# 6
# tensor([ 86,  98, 105])
# 6
# tensor([ 98, 105, 139])
# 6
# tensor([105, 139,  70])
# 6
# tensor([139,  70,  51])
# 6
# tensor([70, 51, 86])
# 6
# tensor([ 51,  86, 112])
# 6
# tensor([ 86, 112, 186])
# 6
# tensor([112, 186, 188])
# 6
# tensor([186, 188,  93])
# 6
# tensor([188,  93, 156])
# 6
# tensor([ 93, 156, 127])
# 6
# tensor([156, 127,  49])
# 6
# tensor([127,  49,  88])
# 6
# tensor([ 49,  88, 194])
# 6
# tensor([ 88, 194, 160])
# 6
# tensor([194, 160,  40])
# 6
# tensor([160,  40, 136])
# 6
# tensor([ 40, 136, 180])
# 6
# tensor([136, 180, 120])
# 6
# tensor([180, 120,  49])
# 6
# tensor([120,  49,  21])
# 6
# tensor([49, 21, 72])
# 6
# tensor([ 21,  72, 113])
# 6
# tensor([ 72, 113,  32])
# 6
# tensor([113,  32, 116])
# 6
# tensor([ 32, 116, 168])
# 6
# tensor([116, 168,  14])
# 6
# tensor([168,  14,   7])
# 6
# tensor([14,  7, 64])
# 6
# tensor([  7,  64, 145])
# 6
# tensor([ 64, 145, 182])
# 6
# tensor([145, 182,   8])
# 6
# tensor([182,   8, 191])
# 6
# tensor([  8, 191,  50])
# 6
# tensor([191,  50,  62])
# 6
# tensor([ 50,  62, 157])
# 6
# tensor([ 62, 157,   2])
# 6
# tensor([157,   2, 100])
# 6
# tensor([  2, 100,  91])
# 6
# tensor([100,  91, 114])
# 6
# tensor([ 91, 114, 175])
# 6
# tensor([114, 175, 140])
# 6
# tensor([175, 140,  96])
# 6
# tensor([140,  96, 170])
# 6
# tensor([ 96, 170, 128])
# 6
# tensor([170, 128,  40])
# 6
# tensor([128,  40,  57])
# 6
# tensor([ 40,  57, 131])
# 6
# tensor([ 57, 131,  52])
# 6
# tensor([131,  52, 147])
# 6
# tensor([ 52, 147, 186])
# 6
# tensor([147, 186,  82])
# 6
# tensor([186,  82, 180])
# 6
# tensor([ 82, 180, 123])
# 6
# tensor([180, 123, 176])
# 6
# tensor([123, 176, 180])
# 6
# tensor([176, 180,  56])
# 6
# tensor([180,  56, 148])
# 6
# tensor([ 56, 148, 135])
# 6
# tensor([148, 135, 174])
# 6
# tensor([135, 174,  67])
# 6
# tensor([174,  67,  81])
# 6
# tensor([ 67,  81, 185])
# 6
# tensor([ 81, 185,  31])
# 6
# tensor([185,  31,  19])
# 6
# tensor([ 31,  19, 149])
# 6
# tensor([ 19, 149, 167])
# 6
# tensor([149, 167, 124])
# 6
# tensor([167, 124,  26])
# 6
# tensor([124,  26, 159])
# 6
# tensor([ 26, 159,  96])
# 6
# ...
# 43
# tensor([ 60,  90, 129])
# 43
# tensor([ 90, 129,  20])
# 43
# tensor([129,  20,   3])
# 43
# tensor([20,  3, 77])
# 43
# tensor([ 3, 77, 40])
# 43
# tensor([ 77,  40, 130])
# 43
# tensor([ 40, 130,  35])
# 43
# tensor([130,  35, 126])
# 43
# tensor([ 35, 126,  22])
# 43
# tensor([126,  22,  33])
# 43
# tensor([22, 33, 95])
# 43
# tensor([ 33,  95, 172])
# 43
# tensor([ 95, 172, 177])
# 43
# tensor([172, 177,   6])
# 43
# tensor([177,   6,  40])
# 43
# tensor([  6,  40, 164])
# 1044.9595310091972
# 44
# tensor([ 92,  69, 180])
# 44
# tensor([ 69, 180, 179])
# 44
# tensor([180, 179,  80])
# 44
# tensor([179,  80,  66])
# 44
# tensor([ 80,  66, 141])
# 44
# tensor([ 66, 141, 163])
# 44
# tensor([141, 163,  72])
# 44
# tensor([163,  72,  29])
# 44
# tensor([72, 29, 85])
# 44
# tensor([29, 85, 97])
# 44
# tensor([85, 97, 24])
# 44
# tensor([ 97,  24, 168])
# 44
# tensor([ 24, 168, 134])
# 44
# tensor([168, 134,  80])
# 44
# tensor([134,  80,  34])
# 44
# tensor([ 80,  34, 180])
# 44
# tensor([ 34, 180,  12])
# 44
# tensor([180,  12,  40])
# 44
# tensor([12, 40, 27])
# 44
# tensor([40, 27, 44])
# 44
# tensor([ 27,  44, 137])
# 44
# tensor([ 44, 137,  47])
# 44
# tensor([137,  47, 183])
# 44
# tensor([ 47, 183,  41])
# 44
# tensor([183,  41,  25])
# 44
# tensor([ 41,  25, 184])
# 44
# tensor([ 25, 184,  40])
# 44
# tensor([184,  40,  17])
# 44
# tensor([40, 17, 11])
# 44
# tensor([ 17,  11, 143])
# 44
# tensor([ 11, 143, 138])
# 44
# tensor([143, 138,  80])
# 44
# tensor([138,  80,  66])
# 44
# tensor([ 80,  66, 154])
# 44
# tensor([ 66, 154,  48])
# 44
# tensor([154,  48,  84])
# 44
# tensor([ 48,  84, 186])
# 44
# tensor([ 84, 186,  47])
# 44
# tensor([186,  47, 183])
# 44
# tensor([ 47, 183, 178])
# 44
# tensor([183, 178,  40])
# 44
# tensor([178,  40, 153])
# 44
# tensor([ 40, 153, 132])
# 44
# tensor([153, 132,  86])
# 44
# tensor([132,  86, 117])
# 44
# tensor([ 86, 117,  37])
# 44
# tensor([117,  37,  13])
# 44
# tensor([37, 13, 49])
# 44
# tensor([ 13,  49, 142])
# 44
# tensor([ 49, 142, 193])
# 44
# tensor([142, 193, 102])
# 44
# tensor([193, 102, 181])
# 44
# tensor([102, 181,  40])
# 44
# tensor([181,  40,   1])
# 44
# tensor([40,  1,  4])
# 44
# tensor([ 1,  4, 35])
# 44
# tensor([  4,  35, 180])
# 44
# tensor([ 35, 180,  63])
# 44
# tensor([180,  63,  40])
# 44
# tensor([63, 40, 75])
# 44
# tensor([40, 75, 28])
# 44
# tensor([75, 28, 48])
# 44
# tensor([ 28,  48, 106])
# 44
# tensor([ 48, 106, 133])
# 44
# tensor([106, 133,  96])
# 44
# tensor([133,  96, 180])
# 44
# tensor([ 96, 180, 169])
# 44
# tensor([180, 169,  89])
# 44
# tensor([169,  89,  18])
# 44
# tensor([89, 18, 87])
# 44
# tensor([18, 87, 86])
# 44
# tensor([87, 86, 98])
# 44
# tensor([ 86,  98, 105])
# 44
# tensor([ 98, 105, 139])
# 44
# tensor([105, 139,  70])
# 44
# tensor([139,  70,  51])
# 44
# tensor([70, 51, 86])
# 44
# tensor([ 51,  86, 112])
# 44
# tensor([ 86, 112, 186])
# 44
# tensor([112, 186, 188])
# 44
# tensor([186, 188,  93])
# 44
# tensor([188,  93, 156])
# 44
# tensor([ 93, 156, 127])
# 44
# tensor([156, 127,  49])
# 44
# tensor([127,  49,  88])
# 44
# tensor([ 49,  88, 194])
# 44
# tensor([ 88, 194, 160])
# 44
# tensor([194, 160,  40])
# 44
# tensor([160,  40, 136])
# 44
# tensor([ 40, 136, 180])
# 44
# tensor([136, 180, 120])
# 44
# tensor([180, 120,  49])
# 44
# tensor([120,  49,  21])
# 44
# tensor([49, 21, 72])
# 44
# tensor([ 21,  72, 113])
# 44
# tensor([ 72, 113,  32])
# 44
# tensor([113,  32, 116])
# 44
# tensor([ 32, 116, 168])
# 44
# tensor([116, 168,  14])
# 44
# tensor([168,  14,   7])
# 44
# tensor([14,  7, 64])
# 44
# tensor([  7,  64, 145])
# 44
# tensor([ 64, 145, 182])
# 44
# tensor([145, 182,   8])
# 44
# tensor([182,   8, 191])
# 44
# tensor([  8, 191,  50])
# 44
# tensor([191,  50,  62])
# 44
# tensor([ 50,  62, 157])
# 44
# tensor([ 62, 157,   2])
# 44
# tensor([157,   2, 100])
# 44
# tensor([  2, 100,  91])
# 44
# tensor([100,  91, 114])
# 44
# tensor([ 91, 114, 175])
# 44
# tensor([114, 175, 140])
# 44
# tensor([175, 140,  96])
# 44
# tensor([140,  96, 170])
# 44
# tensor([ 96, 170, 128])
# 44
# tensor([170, 128,  40])
# 44
# tensor([128,  40,  57])
# 44
# tensor([ 40,  57, 131])
# 44
# tensor([ 57, 131,  52])
# 44
# tensor([131,  52, 147])
# 44
# tensor([ 52, 147, 186])
# 44
# tensor([147, 186,  82])
# 44
# tensor([186,  82, 180])
# 44
# tensor([ 82, 180, 123])
# 44
# tensor([180, 123, 176])
# 44
# tensor([123, 176, 180])
# 44
# tensor([176, 180,  56])
# 44
# tensor([180,  56, 148])
# 44
# tensor([ 56, 148, 135])
# 44
# tensor([148, 135, 174])
# 44
# tensor([135, 174,  67])
# 44
# tensor([174,  67,  81])
# 44
# tensor([ 67,  81, 185])
# 44
# tensor([ 81, 185,  31])
# 44
# tensor([185,  31,  19])
# 44
# tensor([ 31,  19, 149])
# 44
# tensor([ 19, 149, 167])
# 44
# tensor([149, 167, 124])
# 44
# tensor([167, 124,  26])
# 44
# tensor([124,  26, 159])
# 44
# tensor([ 26, 159,  96])
# 44
# tensor([159,  96, 162])
# 44
# tensor([ 96, 162,  61])
# 44
# tensor([162,  61,  96])
# 44
# tensor([ 61,  96, 121])
# 44
# tensor([ 96, 121,  83])
# 44
# tensor([121,  83, 190])
# 44
# tensor([ 83, 190, 110])
# 44
# tensor([190, 110,  58])
# 44
# tensor([110,  58, 101])
# 44
# tensor([ 58, 101, 180])
# 44
# tensor([101, 180, 103])
# 44
# tensor([180, 103,  49])
# 44
# tensor([103,  49, 117])
# 44
# tensor([ 49, 117,  46])
# 44
# tensor([117,  46,  59])
# 44
# tensor([46, 59, 76])
# 44
# tensor([59, 76,  3])
# 44
# tensor([ 76,   3, 146])
# 44
# tensor([  3, 146,  40])
# 44
# tensor([146,  40, 149])
# 44
# tensor([ 40, 149, 118])
# 44
# tensor([149, 118,  85])
# 44
# tensor([118,  85,   5])
# 44
# tensor([85,  5, 96])
# 44
# tensor([  5,  96, 180])
# 44
# tensor([ 96, 180, 158])
# 44
# tensor([180, 158, 104])
# 44
# tensor([158, 104,  10])
# 44
# tensor([104,  10,  96])
# 44
# tensor([ 10,  96, 180])
# 44
# tensor([ 96, 180, 189])
# 44
# tensor([180, 189, 187])
# 44
# tensor([189, 187, 165])
# 44
# tensor([187, 165, 177])
# 44
# tensor([165, 177,  54])
# 44
# tensor([177,  54,  43])
# 44
# tensor([ 54,  43, 166])
# 44
# tensor([ 43, 166,  79])
# 44
# tensor([166,  79,  94])
# 44
# tensor([ 79,  94, 180])
# 44
# tensor([ 94, 180, 192])
# 44
# tensor([180, 192,  49])
# 44
# tensor([192,  49, 117])
# 44
# tensor([ 49, 117, 151])
# 44
# tensor([117, 151, 171])
# 44
# tensor([151, 171, 108])
# 44
# tensor([171, 108, 119])
# 44
# tensor([108, 119, 144])
# 44
# tensor([119, 144,  76])
# 44
# tensor([144,  76, 152])
# 44
# tensor([ 76, 152,  71])
# 44
# tensor([152,  71,  18])
# 44
# tensor([71, 18, 87])
# 44
# tensor([18, 87, 15])
# 44
# tensor([ 87,  15, 125])
# 44
# tensor([ 15, 125,  73])
# 44
# tensor([125,  73, 117])
# 44
# tensor([ 73, 117, 161])
# 44
# tensor([117, 161, 109])
# 44
# tensor([161, 109,  99])
# 44
# tensor([109,  99,  35])
# 44
# tensor([ 99,  35, 180])
# 44
# tensor([ 35, 180, 115])
# 44
# tensor([180, 115,  39])
# 44
# tensor([115,  39, 111])
# 44
# tensor([ 39, 111,  96])
# 44
# tensor([111,  96, 122])
# 44
# tensor([ 96, 122,  30])
# 44
# tensor([122,  30, 133])
# 44
# tensor([ 30, 133,  55])
# 44
# tensor([133,  55,  16])
# 44
# tensor([55, 16, 45])
# 44
# tensor([16, 45, 40])
# 44
# tensor([ 45,  40, 180])
# 44
# tensor([ 40, 180, 173])
# 44
# tensor([180, 173,   0])
# 44
# tensor([173,   0,  65])
# 44
# tensor([  0,  65, 150])
# 44
# tensor([ 65, 150,  74])
# 44
# tensor([150,  74, 129])
# 44
# tensor([ 74, 129,  42])
# 44
# tensor([129,  42,  35])
# 44
# tensor([ 42,  35, 180])
# 44
# tensor([ 35, 180,  36])
# 44
# tensor([180,  36, 107])
# 44
# tensor([ 36, 107,   0])
# 44
# tensor([107,   0, 155])
# 44
# tensor([  0, 155,  40])
# 44
# tensor([155,  40,  68])
# 44
# tensor([40, 68, 23])
# 44
# tensor([ 68,  23, 180])
# 44
# tensor([ 23, 180,   9])
# 44
# tensor([180,   9,  38])
# 44
# tensor([ 9, 38, 53])
# 44
# tensor([ 38,  53, 117])
# 44
# tensor([ 53, 117,  60])
# 44
# tensor([117,  60,  90])
# 44
# tensor([ 60,  90, 129])
# 44
# tensor([ 90, 129,  20])
# 44
# tensor([129,  20,   3])
# 44
# tensor([20,  3, 77])
# 44
# tensor([ 3, 77, 40])
# 44
# tensor([ 77,  40, 130])
# 44
# tensor([ 40, 130,  35])
# 44
# tensor([130,  35, 126])
# 44
# tensor([ 35, 126,  22])
# 44
# tensor([126,  22,  33])
# 44
# tensor([22, 33, 95])
# 44
# tensor([ 33,  95, 172])
# 44
# tensor([ 95, 172, 177])
# 44
# tensor([172, 177,   6])
# 44
# tensor([177,   6,  40])
# 44
# tensor([  6,  40, 164])
# 1037.6334186196327
# 45
# tensor([ 92,  69, 180])
# 45
# tensor([ 69, 180, 179])
# 45
# tensor([180, 179,  80])
# 45
# tensor([179,  80,  66])
# 45
# tensor([ 80,  66, 141])
# 45
# tensor([ 66, 141, 163])
# 45
# tensor([141, 163,  72])
# 45
# tensor([163,  72,  29])
# 45
# tensor([72, 29, 85])
# 45
# tensor([29, 85, 97])
# 45
# tensor([85, 97, 24])
# 45
# tensor([ 97,  24, 168])
# 45
# tensor([ 24, 168, 134])
# 45
# tensor([168, 134,  80])
# 45
# tensor([134,  80,  34])
# 45
# tensor([ 80,  34, 180])
# 45
# tensor([ 34, 180,  12])
# 45
# tensor([180,  12,  40])
# 45
# tensor([12, 40, 27])
# 45
# tensor([40, 27, 44])
# 45
# tensor([ 27,  44, 137])
# 45
# tensor([ 44, 137,  47])
# 45
# tensor([137,  47, 183])
# 45
# tensor([ 47, 183,  41])
# 45
# tensor([183,  41,  25])
# 45
# tensor([ 41,  25, 184])
# 45
# tensor([ 25, 184,  40])
# 45
# tensor([184,  40,  17])
# 45
# tensor([40, 17, 11])
# 45
# tensor([ 17,  11, 143])
# 45
# tensor([ 11, 143, 138])
# 45
# tensor([143, 138,  80])
# 45
# tensor([138,  80,  66])
# 45
# tensor([ 80,  66, 154])
# 45
# tensor([ 66, 154,  48])
# 45
# tensor([154,  48,  84])
# 45
# tensor([ 48,  84, 186])
# 45
# tensor([ 84, 186,  47])
# 45
# tensor([186,  47, 183])
# 45
# tensor([ 47, 183, 178])
# 45
# tensor([183, 178,  40])
# 45
# tensor([178,  40, 153])
# 45
# tensor([ 40, 153, 132])
# 45
# tensor([153, 132,  86])
# 45
# tensor([132,  86, 117])
# 45
# tensor([ 86, 117,  37])
# 45
# tensor([117,  37,  13])
# 45
# tensor([37, 13, 49])
# 45
# tensor([ 13,  49, 142])
# 45
# tensor([ 49, 142, 193])
# 45
# tensor([142, 193, 102])
# 45
# tensor([193, 102, 181])
# 45
# tensor([102, 181,  40])
# 45
# tensor([181,  40,   1])
# 45
# tensor([40,  1,  4])
# 45
# tensor([ 1,  4, 35])
# 45
# tensor([  4,  35, 180])
# 45
# tensor([ 35, 180,  63])
# 45
# tensor([180,  63,  40])
# 45
# tensor([63, 40, 75])
# 45
# tensor([40, 75, 28])
# 45
# tensor([75, 28, 48])
# 45
# tensor([ 28,  48, 106])
# 45
# tensor([ 48, 106, 133])
# 45
# tensor([106, 133,  96])
# 45
# tensor([133,  96, 180])
# 45
# tensor([ 96, 180, 169])
# 45
# tensor([180, 169,  89])
# 45
# tensor([169,  89,  18])
# 45
# tensor([89, 18, 87])
# 45
# tensor([18, 87, 86])
# 45
# tensor([87, 86, 98])
# 45
# tensor([ 86,  98, 105])
# 45
# tensor([ 98, 105, 139])
# 45
# tensor([105, 139,  70])
# 45
# tensor([139,  70,  51])
# 45
# tensor([70, 51, 86])
# 45
# tensor([ 51,  86, 112])
# 45
# tensor([ 86, 112, 186])
# 45
# tensor([112, 186, 188])
# 45
# tensor([186, 188,  93])
# 45
# tensor([188,  93, 156])
# 45
# tensor([ 93, 156, 127])
# 45
# tensor([156, 127,  49])
# 45
# tensor([127,  49,  88])
# 45
# tensor([ 49,  88, 194])
# 45
# tensor([ 88, 194, 160])
# 45
# tensor([194, 160,  40])
# 45
# tensor([160,  40, 136])
# 45
# tensor([ 40, 136, 180])
# 45
# tensor([136, 180, 120])
# 45
# tensor([180, 120,  49])
# 45
# tensor([120,  49,  21])
# 45
# tensor([49, 21, 72])
# 45
# tensor([ 21,  72, 113])
# 45
# tensor([ 72, 113,  32])
# 45
# tensor([113,  32, 116])
# 45
# tensor([ 32, 116, 168])
# 45
# tensor([116, 168,  14])
# 45
# tensor([168,  14,   7])
# 45
# tensor([14,  7, 64])
# 45
# tensor([  7,  64, 145])
# 45
# tensor([ 64, 145, 182])
# 45
# tensor([145, 182,   8])
# 45
# tensor([182,   8, 191])
# 45
# tensor([  8, 191,  50])
# 45
# tensor([191,  50,  62])
# 45
# tensor([ 50,  62, 157])
# 45
# tensor([ 62, 157,   2])
# 45
# tensor([157,   2, 100])
# 45
# tensor([  2, 100,  91])
# 45
# tensor([100,  91, 114])
# 45
# tensor([ 91, 114, 175])
# 45
# tensor([114, 175, 140])
# 45
# tensor([175, 140,  96])
# 45
# tensor([140,  96, 170])
# 45
# tensor([ 96, 170, 128])
# 45
# tensor([170, 128,  40])
# 45
# tensor([128,  40,  57])
# 45
# tensor([ 40,  57, 131])
# 45
# tensor([ 57, 131,  52])
# 45
# tensor([131,  52, 147])
# 45
# tensor([ 52, 147, 186])
# 45
# tensor([147, 186,  82])
# 45
# tensor([186,  82, 180])
# 45
# tensor([ 82, 180, 123])
# 45
# tensor([180, 123, 176])
# 45
# tensor([123, 176, 180])
# 45
# tensor([176, 180,  56])
# 45
# tensor([180,  56, 148])
# 45
# tensor([ 56, 148, 135])
# 45
# tensor([148, 135, 174])
# 45
# tensor([135, 174,  67])
# 45
# tensor([174,  67,  81])
# 45
# tensor([ 67,  81, 185])
# 45
# tensor([ 81, 185,  31])
# 45
# tensor([185,  31,  19])
# 45
# tensor([ 31,  19, 149])
# 45
# tensor([ 19, 149, 167])
# 45
# tensor([149, 167, 124])
# 45
# tensor([167, 124,  26])
# 45
# tensor([124,  26, 159])
# 45
# tensor([ 26, 159,  96])
# 45
# tensor([159,  96, 162])
# 45
# tensor([ 96, 162,  61])
# 45
# tensor([162,  61,  96])
# 45
# tensor([ 61,  96, 121])
# 45
# tensor([ 96, 121,  83])
# 45
# tensor([121,  83, 190])
# 45
# tensor([ 83, 190, 110])
# 45
# tensor([190, 110,  58])
# 45
# tensor([110,  58, 101])
# 45
# tensor([ 58, 101, 180])
# 45
# tensor([101, 180, 103])
# 45
# tensor([180, 103,  49])
# 45
# tensor([103,  49, 117])
# 45
# tensor([ 49, 117,  46])
# 45
# tensor([117,  46,  59])
# 45
# tensor([46, 59, 76])
# 45
# tensor([59, 76,  3])
# 45
# tensor([ 76,   3, 146])
# 45
# tensor([  3, 146,  40])
# 45
# tensor([146,  40, 149])
# 45
# tensor([ 40, 149, 118])
# 45
# tensor([149, 118,  85])
# 45
# tensor([118,  85,   5])
# 45
# tensor([85,  5, 96])
# 45
# tensor([  5,  96, 180])
# 45
# tensor([ 96, 180, 158])
# 45
# tensor([180, 158, 104])
# 45
# tensor([158, 104,  10])
# 45
# tensor([104,  10,  96])
# 45
# tensor([ 10,  96, 180])
# 45
# tensor([ 96, 180, 189])
# 45
# tensor([180, 189, 187])
# 45
# tensor([189, 187, 165])
# 45
# tensor([187, 165, 177])
# 45
# tensor([165, 177,  54])
# 45
# tensor([177,  54,  43])
# 45
# tensor([ 54,  43, 166])
# 45
# tensor([ 43, 166,  79])
# 45
# tensor([166,  79,  94])
# 45
# tensor([ 79,  94, 180])
# 45
# tensor([ 94, 180, 192])
# 45
# tensor([180, 192,  49])
# 45
# tensor([192,  49, 117])
# 45
# tensor([ 49, 117, 151])
# 45
# tensor([117, 151, 171])
# 45
# tensor([151, 171, 108])
# 45
# tensor([171, 108, 119])
# 45
# tensor([108, 119, 144])
# 45
# tensor([119, 144,  76])
# 45
# tensor([144,  76, 152])
# 45
# tensor([ 76, 152,  71])
# 45
# tensor([152,  71,  18])
# 45
# tensor([71, 18, 87])
# 45
# tensor([18, 87, 15])
# 45
# tensor([ 87,  15, 125])
# 45
# tensor([ 15, 125,  73])
# 45
# tensor([125,  73, 117])
# 45
# tensor([ 73, 117, 161])
# 45
# tensor([117, 161, 109])
# 45
# tensor([161, 109,  99])
# 45
# tensor([109,  99,  35])
# 45
# tensor([ 99,  35, 180])
# 45
# tensor([ 35, 180, 115])
# 45
# tensor([180, 115,  39])
# 45
# tensor([115,  39, 111])
# 45
# tensor([ 39, 111,  96])
# 45
# tensor([111,  96, 122])
# 45
# tensor([ 96, 122,  30])
# 45
# tensor([122,  30, 133])
# 45
# tensor([ 30, 133,  55])
# 45
# tensor([133,  55,  16])
# 45
# tensor([55, 16, 45])
# 45
# tensor([16, 45, 40])
# 45
# tensor([ 45,  40, 180])
# 45
# tensor([ 40, 180, 173])
# 45
# tensor([180, 173,   0])
# 45
# tensor([173,   0,  65])
# 45
# tensor([  0,  65, 150])
# 45
# tensor([ 65, 150,  74])
# 45
# tensor([150,  74, 129])
# 45
# tensor([ 74, 129,  42])
# 45
# tensor([129,  42,  35])
# 45
# tensor([ 42,  35, 180])
# 45
# tensor([ 35, 180,  36])
# 45
# tensor([180,  36, 107])
# 45
# tensor([ 36, 107,   0])
# 45
# tensor([107,   0, 155])
# 45
# tensor([  0, 155,  40])
# 45
# tensor([155,  40,  68])
# 45
# tensor([40, 68, 23])
# 45
# tensor([ 68,  23, 180])
# 45
# tensor([ 23, 180,   9])
# 45
# tensor([180,   9,  38])
# 45
# tensor([ 9, 38, 53])
# 45
# tensor([ 38,  53, 117])
# 45
# tensor([ 53, 117,  60])
# 45
# tensor([117,  60,  90])
# 45
# tensor([ 60,  90, 129])
# 45
# tensor([ 90, 129,  20])
# 45
# tensor([129,  20,   3])
# 45
# tensor([20,  3, 77])
# 45
# tensor([ 3, 77, 40])
# 45
# tensor([ 77,  40, 130])
# 45
# tensor([ 40, 130,  35])
# 45
# tensor([130,  35, 126])
# 45
# tensor([ 35, 126,  22])
# 45
# tensor([126,  22,  33])
# 45
# tensor([22, 33, 95])
# 45
# tensor([ 33,  95, 172])
# 45
# tensor([ 95, 172, 177])
# 45
# tensor([172, 177,   6])
# 45
# tensor([177,   6,  40])
# 45
# tensor([  6,  40, 164])
# 1030.260410308838
# 46
# tensor([ 92,  69, 180])
# 46
# tensor([ 69, 180, 179])
# 46
# tensor([180, 179,  80])
# 46
# tensor([179,  80,  66])
# 46
# tensor([ 80,  66, 141])
# 46
# tensor([ 66, 141, 163])
# 46
# tensor([141, 163,  72])
# 46
# tensor([163,  72,  29])
# 46
# tensor([72, 29, 85])
# 46
# tensor([29, 85, 97])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 167
#     163 loss = loss_function(log_probs, torch.tensor([word_to_ix[target]], dtype=torch.long))
#     164 #print(loss)
#     165
#     166 # Step 5. Do the backward pass and update the gradient
# --> 167 loss.backward()
#     168 optimizer.step()
#     170 # Get the Python number from a 1-element Tensor by calling tensor.item()
#
# File ~\anaconda3\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\anaconda3\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
for context , target in ngrams:
    context_idxs = torch.tensor([word_to_ix[w] for w in context],dtype=torch.long)
    print(context)
    print(context_idxs)
# Out:
# ['Empathy', 'for', 'the']
# tensor([ 92,  69, 180])
# ['for', 'the', 'poor']
# tensor([ 69, 180, 179])
# ['the', 'poor', 'may']
# tensor([180, 179,  80])
# ['poor', 'may', 'not']
# tensor([179,  80,  66])
# ['may', 'not', 'come']
# tensor([ 80,  66, 141])
# ['not', 'come', 'easily']
# tensor([ 66, 141, 163])
# ['come', 'easily', 'to']
# tensor([141, 163,  72])
# ['easily', 'to', 'people']
# tensor([163,  72,  29])
# ['to', 'people', 'who']
# tensor([72, 29, 85])
# ['people', 'who', 'never']
# tensor([29, 85, 97])
# ['who', 'never', 'experienced']
# tensor([85, 97, 24])
# ['never', 'experienced', 'it.']
# tensor([ 97,  24, 168])
# ['experienced', 'it.', 'They']
# tensor([ 24, 168, 134])
# ['it.', 'They', 'may']
# tensor([168, 134,  80])
# ['They', 'may', 'blame']
# tensor([134,  80,  34])
# ['may', 'blame', 'the']
# tensor([ 80,  34, 180])
# ['blame', 'the', 'victims']
# tensor([ 34, 180,  12])
# ['the', 'victims', 'and']
# tensor([180,  12,  40])
# ['victims', 'and', 'insist']
# tensor([12, 40, 27])
# ['and', 'insist', 'their']
# tensor([40, 27, 44])
# ['insist', 'their', 'predicament']
# tensor([ 27,  44, 137])
# ['their', 'predicament', 'can']
# tensor([ 44, 137,  47])
# ['predicament', 'can', 'be']
# tensor([137,  47, 183])
# ['can', 'be', 'overcome']
# tensor([ 47, 183,  41])
# ['be', 'overcome', 'through']
# tensor([183,  41,  25])
# ['overcome', 'through', 'determination']
# tensor([ 41,  25, 184])
# ['through', 'determination', 'and']
# tensor([ 25, 184,  40])
# ['determination', 'and', 'hard']
# tensor([184,  40,  17])
# ['and', 'hard', 'work.']
# tensor([40, 17, 11])
# ['hard', 'work.', 'But']
# tensor([ 17,  11, 143])
# ['work.', 'But', 'they']
# tensor([ 11, 143, 138])
# ['But', 'they', 'may']
# tensor([143, 138,  80])
# ['they', 'may', 'not']
# tensor([138,  80,  66])
# ['may', 'not', 'realize']
# tensor([ 80,  66, 154])
# ['not', 'realize', 'that']
# tensor([ 66, 154,  48])
# ['realize', 'that', 'extreme']
# tensor([154,  48,  84])
# ['that', 'extreme', 'poverty']
# tensor([ 48,  84, 186])
# ['extreme', 'poverty', 'can']
# tensor([ 84, 186,  47])
# ['poverty', 'can', 'be']
# tensor([186,  47, 183])
# ['can', 'be', 'psychologically']
# tensor([ 47, 183, 178])
# ['be', 'psychologically', 'and']
# tensor([183, 178,  40])
# ['psychologically', 'and', 'physically']
# tensor([178,  40, 153])
# ['and', 'physically', 'incapacitating']
# tensor([ 40, 153, 132])
# ['physically', 'incapacitating', '—']
# tensor([153, 132,  86])
# ['incapacitating', '—', 'a']
# tensor([132,  86, 117])
# ['—', 'a', 'perpetual']
# tensor([ 86, 117,  37])
# ['a', 'perpetual', 'cycle']
# tensor([117,  37,  13])
# ['perpetual', 'cycle', 'of']
# tensor([37, 13, 49])
# ['cycle', 'of', 'bad']
# tensor([ 13,  49, 142])
# ['of', 'bad', 'diets,']
# tensor([ 49, 142, 193])
# ['bad', 'diets,', 'health']
# tensor([142, 193, 102])
# ['diets,', 'health', 'care']
# tensor([193, 102, 181])
# ['health', 'care', 'and']
# tensor([102, 181,  40])
# ['care', 'and', 'education']
# tensor([181,  40,   1])
# ['and', 'education', 'exacerbated']
# tensor([40,  1,  4])
# ['education', 'exacerbated', 'by']
# tensor([ 1,  4, 35])
# ['exacerbated', 'by', 'the']
# tensor([  4,  35, 180])
# ['by', 'the', 'shaming']
# tensor([ 35, 180,  63])
# ['the', 'shaming', 'and']
# tensor([180,  63,  40])
# ['shaming', 'and', 'self-fulfilling']
# tensor([63, 40, 75])
# ['and', 'self-fulfilling', 'prophecies']
# tensor([40, 75, 28])
# ['self-fulfilling', 'prophecies', 'that']
# tensor([75, 28, 48])
# ['prophecies', 'that', 'define']
# tensor([ 28,  48, 106])
# ['that', 'define', 'it']
# tensor([ 48, 106, 133])
# ['define', 'it', 'in']
# tensor([106, 133,  96])
# ['it', 'in', 'the']
# tensor([133,  96, 180])
# ['in', 'the', 'public']
# tensor([ 96, 180, 169])
# ['the', 'public', 'imagination.']
# tensor([180, 169,  89])
# ['public', 'imagination.', 'Gordon']
# tensor([169,  89,  18])
# ['imagination.', 'Gordon', 'Parks']
# tensor([89, 18, 87])
# ['Gordon', 'Parks', '—']
# tensor([18, 87, 86])
# ['Parks', '—', 'perhaps']
# tensor([87, 86, 98])
# ['—', 'perhaps', 'more']
# tensor([ 86,  98, 105])
# ['perhaps', 'more', 'than']
# tensor([ 98, 105, 139])
# ['more', 'than', 'any']
# tensor([105, 139,  70])
# ['than', 'any', 'artist']
# tensor([139,  70,  51])
# ['any', 'artist', '—']
# tensor([70, 51, 86])
# ['artist', '—', 'saw']
# tensor([ 51,  86, 112])
# ['—', 'saw', 'poverty']
# tensor([ 86, 112, 186])
# ['saw', 'poverty', 'as']
# tensor([112, 186, 188])
# ['poverty', 'as', '“the']
# tensor([186, 188,  93])
# ['as', '“the', 'most']
# tensor([188,  93, 156])
# ['“the', 'most', 'savage']
# tensor([ 93, 156, 127])
# ['most', 'savage', 'of']
# tensor([156, 127,  49])
# ['savage', 'of', 'all']
# tensor([127,  49,  88])
# ['of', 'all', 'human']
# tensor([ 49,  88, 194])
# ['all', 'human', 'afflictions”']
# tensor([ 88, 194, 160])
# ['human', 'afflictions”', 'and']
# tensor([194, 160,  40])
# ['afflictions”', 'and', 'realized']
# tensor([160,  40, 136])
# ['and', 'realized', 'the']
# tensor([ 40, 136, 180])
# ['realized', 'the', 'power']
# tensor([136, 180, 120])
# ['the', 'power', 'of']
# tensor([180, 120,  49])
# ['power', 'of', 'empathy']
# tensor([120,  49,  21])
# ['of', 'empathy', 'to']
# tensor([49, 21, 72])
# ['empathy', 'to', 'help']
# tensor([ 21,  72, 113])
# ['to', 'help', 'us']
# tensor([ 72, 113,  32])
# ['help', 'us', 'understand']
# tensor([113,  32, 116])
# ['us', 'understand', 'it.']
# tensor([ 32, 116, 168])
# ['understand', 'it.', 'It']
# tensor([116, 168,  14])
# ['it.', 'It', 'was']
# tensor([168,  14,   7])
# ['It', 'was', 'neither']
# tensor([14,  7, 64])
# ['was', 'neither', 'an']
# tensor([  7,  64, 145])
# ['neither', 'an', 'abstract']
# tensor([ 64, 145, 182])
# ['an', 'abstract', 'problem']
# tensor([145, 182,   8])
# ['abstract', 'problem', 'nor']
# tensor([182,   8, 191])
# ['problem', 'nor', 'political']
# tensor([  8, 191,  50])
# ['nor', 'political', 'symbol,']
# tensor([191,  50,  62])
# ['political', 'symbol,', 'but']
# tensor([ 50,  62, 157])
# ['symbol,', 'but', 'something']
# tensor([ 62, 157,   2])
# ['but', 'something', 'he']
# tensor([157,   2, 100])
# ['something', 'he', 'endured']
# tensor([  2, 100,  91])
# ['he', 'endured', 'growing']
# tensor([100,  91, 114])
# ['endured', 'growing', 'up']
# tensor([ 91, 114, 175])
# ['growing', 'up', 'destitute']
# tensor([114, 175, 140])
# ['up', 'destitute', 'in']
# tensor([175, 140,  96])
# ['destitute', 'in', 'rural']
# tensor([140,  96, 170])
# ['in', 'rural', 'Kansas']
# tensor([ 96, 170, 128])
# ['rural', 'Kansas', 'and']
# tensor([170, 128,  40])
# ['Kansas', 'and', 'having']
# tensor([128,  40,  57])
# ['and', 'having', 'spent']
# tensor([ 40,  57, 131])
# ['having', 'spent', 'years']
# tensor([ 57, 131,  52])
# ['spent', 'years', 'documenting']
# tensor([131,  52, 147])
# ['years', 'documenting', 'poverty']
# tensor([ 52, 147, 186])
# ['documenting', 'poverty', 'throughout']
# tensor([147, 186,  82])
# ['poverty', 'throughout', 'the']
# tensor([186,  82, 180])
# ['throughout', 'the', 'world,']
# tensor([ 82, 180, 123])
# ['the', 'world,', 'including']
# tensor([180, 123, 176])
# ['world,', 'including', 'the']
# tensor([123, 176, 180])
# ['including', 'the', 'United']
# tensor([176, 180,  56])
# ['the', 'United', 'States.']
# tensor([180,  56, 148])
# ['United', 'States.', 'That']
# tensor([ 56, 148, 135])
# ['States.', 'That', 'sensitivity']
# tensor([148, 135, 174])
# ['That', 'sensitivity', 'informed']
# tensor([135, 174,  67])
# ['sensitivity', 'informed', '“Freedom’s']
# tensor([174,  67,  81])
# ['informed', '“Freedom’s', 'Fearful']
# tensor([ 67,  81, 185])
# ['“Freedom’s', 'Fearful', 'Foe:']
# tensor([ 81, 185,  31])
# ['Fearful', 'Foe:', 'Poverty,”']
# tensor([185,  31,  19])
# ['Foe:', 'Poverty,”', 'his']
# tensor([ 31,  19, 149])
# ['Poverty,”', 'his', 'celebrated']
# tensor([ 19, 149, 167])
# ['his', 'celebrated', 'photo']
# tensor([149, 167, 124])
# ['celebrated', 'photo', 'essay']
# tensor([167, 124,  26])
# ['photo', 'essay', 'published']
# tensor([124,  26, 159])
# ['essay', 'published', 'in']
# tensor([ 26, 159,  96])
# ['published', 'in', 'Life']
# tensor([159,  96, 162])
# ['in', 'Life', 'magazine']
# tensor([ 96, 162,  61])
# ['Life', 'magazine', 'in']
# tensor([162,  61,  96])
# ['magazine', 'in', 'June']
# tensor([ 61,  96, 121])
# ['in', 'June', '1961.']
# tensor([ 96, 121,  83])
# ['June', '1961.', 'He']
# tensor([121,  83, 190])
# ['1961.', 'He', 'took']
# tensor([ 83, 190, 110])
# ['He', 'took', 'readers']
# tensor([190, 110,  58])
# ['took', 'readers', 'into']
# tensor([110,  58, 101])
# ['readers', 'into', 'the']
# tensor([ 58, 101, 180])
# ['into', 'the', 'lives']
# tensor([101, 180, 103])
# ['the', 'lives', 'of']
# tensor([180, 103,  49])
# ['lives', 'of', 'a']
# tensor([103,  49, 117])
# ['of', 'a', 'Brazilian']
# tensor([ 49, 117,  46])
# ['a', 'Brazilian', 'boy,']
# tensor([117,  46,  59])
# ['Brazilian', 'boy,', 'Flavio']
# tensor([46, 59, 76])
# ['boy,', 'Flavio', 'da']
# tensor([59, 76,  3])
# ['Flavio', 'da', 'Silva,']
# tensor([ 76,   3, 146])
# ['da', 'Silva,', 'and']
# tensor([  3, 146,  40])
# ['Silva,', 'and', 'his']
# tensor([146,  40, 149])
# ['and', 'his', 'family,']
# tensor([ 40, 149, 118])
# ['his', 'family,', 'who']
# tensor([149, 118,  85])
# ['family,', 'who', 'lived']
# tensor([118,  85,   5])
# ['who', 'lived', 'in']
# tensor([85,  5, 96])
# ['lived', 'in', 'the']
# tensor([  5,  96, 180])
# ['in', 'the', 'ramshackle']
# tensor([ 96, 180, 158])
# ['the', 'ramshackle', 'Catacumba']
# tensor([180, 158, 104])
# ['ramshackle', 'Catacumba', 'favela']
# tensor([158, 104,  10])
# ['Catacumba', 'favela', 'in']
# tensor([104,  10,  96])
# ['favela', 'in', 'the']
# tensor([ 10,  96, 180])
# ['in', 'the', 'hills']
# tensor([ 96, 180, 189])
# ['the', 'hills', 'outside']
# tensor([180, 189, 187])
# ['hills', 'outside', 'Rio']
# tensor([189, 187, 165])
# ['outside', 'Rio', 'de']
# tensor([187, 165, 177])
# ['Rio', 'de', 'Janeiro.']
# tensor([165, 177,  54])
# ['de', 'Janeiro.', 'These']
# tensor([177,  54,  43])
# ['Janeiro.', 'These', 'stark']
# tensor([ 54,  43, 166])
# ['These', 'stark', 'photographs']
# tensor([ 43, 166,  79])
# ['stark', 'photographs', 'are']
# tensor([166,  79,  94])
# ['photographs', 'are', 'the']
# tensor([ 79,  94, 180])
# ['are', 'the', 'subject']
# tensor([ 94, 180, 192])
# ['the', 'subject', 'of']
# tensor([180, 192,  49])
# ['subject', 'of', 'a']
# tensor([192,  49, 117])
# ['of', 'a', 'new']
# tensor([ 49, 117, 151])
# ['a', 'new', 'book,']
# tensor([117, 151, 171])
# ['new', 'book,', '“Gordon']
# tensor([151, 171, 108])
# ['book,', '“Gordon', 'Parks:']
# tensor([171, 108, 119])
# ['“Gordon', 'Parks:', 'The']
# tensor([108, 119, 144])
# ['Parks:', 'The', 'Flavio']
# tensor([119, 144,  76])
# ['The', 'Flavio', 'Story”']
# tensor([144,  76, 152])
# ['Flavio', 'Story”', '(Steidl/The']
# tensor([ 76, 152,  71])
# ['Story”', '(Steidl/The', 'Gordon']
# tensor([152,  71,  18])
# ['(Steidl/The', 'Gordon', 'Parks']
# tensor([71, 18, 87])
# ['Gordon', 'Parks', 'Foundation),']
# tensor([18, 87, 15])
# ['Parks', 'Foundation),', 'which']
# tensor([ 87,  15, 125])
# ['Foundation),', 'which', 'accompanies']
# tensor([ 15, 125,  73])
# ['which', 'accompanies', 'a']
# tensor([125,  73, 117])
# ['accompanies', 'a', 'traveling']
# tensor([ 73, 117, 161])
# ['a', 'traveling', 'exhibition']
# tensor([117, 161, 109])
# ['traveling', 'exhibition', 'co-organized']
# tensor([161, 109,  99])
# ['exhibition', 'co-organized', 'by']
# tensor([109,  99,  35])
# ['co-organized', 'by', 'the']
# tensor([ 99,  35, 180])
# ['by', 'the', 'Ryerson']
# tensor([ 35, 180, 115])
# ['the', 'Ryerson', 'Image']
# tensor([180, 115,  39])
# ['Ryerson', 'Image', 'Centre']
# tensor([115,  39, 111])
# ['Image', 'Centre', 'in']
# tensor([ 39, 111,  96])
# ['Centre', 'in', 'Toronto,']
# tensor([111,  96, 122])
# ['in', 'Toronto,', 'where']
# tensor([ 96, 122,  30])
# ['Toronto,', 'where', 'it']
# tensor([122,  30, 133])
# ['where', 'it', 'opens']
# tensor([ 30, 133,  55])
# ['it', 'opens', 'this']
# tensor([133,  55,  16])
# ['opens', 'this', 'week,']
# tensor([55, 16, 45])
# ['this', 'week,', 'and']
# tensor([16, 45, 40])
# ['week,', 'and', 'the']
# tensor([ 45,  40, 180])
# ['and', 'the', 'J.']
# tensor([ 40, 180, 173])
# ['the', 'J.', 'Paul']
# tensor([180, 173,   0])
# ['J.', 'Paul', 'Getty']
# tensor([173,   0,  65])
# ['Paul', 'Getty', 'Museum.']
# tensor([  0,  65, 150])
# ['Getty', 'Museum.', 'Edited']
# tensor([ 65, 150,  74])
# ['Museum.', 'Edited', 'with']
# tensor([150,  74, 129])
# ['Edited', 'with', 'texts']
# tensor([ 74, 129,  42])
# ['with', 'texts', 'by']
# tensor([129,  42,  35])
# ['texts', 'by', 'the']
# tensor([ 42,  35, 180])
# ['by', 'the', 'exhibition’s']
# tensor([ 35, 180,  36])
# ['the', 'exhibition’s', 'co-curators,']
# tensor([180,  36, 107])
# ['exhibition’s', 'co-curators,', 'Paul']
# tensor([ 36, 107,   0])
# ['co-curators,', 'Paul', 'Roth']
# tensor([107,   0, 155])
# ['Paul', 'Roth', 'and']
# tensor([  0, 155,  40])
# ['Roth', 'and', 'Amanda']
# tensor([155,  40,  68])
# ['and', 'Amanda', 'Maddox,']
# tensor([40, 68, 23])
# ['Amanda', 'Maddox,', 'the']
# tensor([ 68,  23, 180])
# ['Maddox,', 'the', 'book']
# tensor([ 23, 180,   9])
# ['the', 'book', 'also']
# tensor([180,   9,  38])
# ['book', 'also', 'includes']
# tensor([ 9, 38, 53])
# ['also', 'includes', 'a']
# tensor([ 38,  53, 117])
# ['includes', 'a', 'recent']
# tensor([ 53, 117,  60])
# ['a', 'recent', 'interview']
# tensor([117,  60,  90])
# ['recent', 'interview', 'with']
# tensor([ 60,  90, 129])
# ['interview', 'with', 'Mr.']
# tensor([ 90, 129,  20])
# ['with', 'Mr.', 'da']
# tensor([129,  20,   3])
# ['Mr.', 'da', 'Silva']
# tensor([20,  3, 77])
# ['da', 'Silva', 'and']
# tensor([ 3, 77, 40])
# ['Silva', 'and', 'essays']
# tensor([ 77,  40, 130])
# ['and', 'essays', 'by']
# tensor([ 40, 130,  35])
# ['essays', 'by', 'Beatriz']
# tensor([130,  35, 126])
# ['by', 'Beatriz', 'Jaguaribe,']
# tensor([ 35, 126,  22])
# ['Beatriz', 'Jaguaribe,', 'Maria']
# tensor([126,  22,  33])
# ['Jaguaribe,', 'Maria', 'Alice']
# tensor([22, 33, 95])
# ['Maria', 'Alice', 'Rezende']
# tensor([ 33,  95, 172])
# ['Alice', 'Rezende', 'de']
# tensor([ 95, 172, 177])
# ['Rezende', 'de', 'Carvalho']
# tensor([172, 177,   6])
# ['de', 'Carvalho', 'and']
# tensor([177,   6,  40])
# ['Carvalho', 'and', 'Sérgio']
# tensor([  6,  40, 164])
